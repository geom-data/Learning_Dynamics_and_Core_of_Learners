# %%
## First import packages
import numpy as np
import tensorflow as tf
import keras
from keras import Model
import os, glob
import resnet_modified # modified to have zero verbosity, deperacated several printing step, lr -> learning_rate in calling adam.
from keras.datasets import cifar10
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from resnet_modified import ResNet
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.models import load_model
from keras import layers
from keras.layers import Dense
import pandas as pd

## Define local labeling dictionary and functions
## Function: learning rate schedule
## This is used in specialization method
## Fundtion: Specialization
## This is method of logifold. Customized here adopting local load and usage.
label_dict = {(3,1) : 'ResNet20v1',
        (3,2) : 'ResNet20v2',
        (9,1): 'ResNet56v1',
        (9,2): 'ResNet56v2'}

def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 5, 10, 15, 18 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 18:
        lr *= 0.5e-3
    elif epoch > 15:
        lr *= 1e-3
    elif epoch > 10:
        lr *= 1e-2
    elif epoch > 5:
        lr *= 1e-1
#     print('Learning rate: ', lr)
    return lr

def turn_specialist(model : Model, path : str,
        x_tr: np.ndarray | None = None,
        y_tr: np.ndarray | None = None,
        x_v: np.ndarray | None = None,
        y_v: np.ndarray | None = None,
        epochs: int = 21,
        learning_rate : float = 1e-3,
        batch_size: int = 128,
        save_each: bool = False,
        save_bests: int | None = None,
        verbose: int = 1,
    ):
        
        # build specialist network
        base = Model(inputs = model.inputs, outputs = model.layers[-2].output, name="base")
        x    = keras.Input(shape=base.input_shape[1:], name="in")
        y    = Dense(10, name="dense")(base(x)) # 10 can be changed to len(newtarget)
        z    = layers.Softmax(name="softmax")(y)
        specialist = Model(inputs = x, outputs = z)
        specialist.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
            loss="categorical_crossentropy",
            metrics=["accuracy"],
        )



        # callbacks
        callbacks = [ModelCheckpoint(path, monitor="val_accuracy",
                                    save_best_only=True, verbose=verbose)]
        
        callbacks += [LearningRateScheduler(lr_schedule),
                        ReduceLROnPlateau(factor=np.sqrt(0.1), patience=5, min_lr=5e-7)]

        # fit 
        hist = specialist.fit(x_tr, y_tr, batch_size=batch_size,
                        validation_data=(x_v, y_v),
                        epochs=epochs, callbacks=callbacks, verbose=verbose)



        # ---------- summary ----------
        metric = "val_accuracy"
        best = np.max(hist.history[metric])
        first = hist.history[metric][0]
        print(f"best {metric} {best:.3f} (first {first:.3f})")
    
## Load data and preprocess a bit.
(x, y), (x_test, y_test) = cifar10.load_data()
x_train, x_v, y_train, y_v = train_test_split(x, y, test_size=0.2, 
                                              random_state=42) # random state has been always 42.
x_train = x_train.astype('float32') / 255.0
x_val = x_v.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train_categorical_10 = to_categorical(y_train,10)
y_val_categorical_10 = to_categorical(y_v,10)
y_test_categorical_10 = to_categorical(y_test,10)
y_test_categorical_20 = to_categorical(y_test,20)

training_y_long=np.concatenate([y_train,y_train+10],axis=0)
training_y_long = keras.utils.to_categorical(training_y_long,20)
validating_y_long=np.concatenate([y_v,y_v+10],axis=0)
validating_y_long = keras.utils.to_categorical(validating_y_long,20)

# %%
## Define custom function for generating result table.

def make_df(results:dict, single:bool = False):
    rows = []
    if not single:
        
        for (structure, attack_type), eval_dict in results.items():
            accs = [eval_dict.get(f'acc_{i}', np.nan) for i in range(len(eval_dict))]
            accs.sort(reverse = True)
            acc_av = np.nanmean(accs)
            losses = [eval_dict.get(f'loss_{i}', np.nan) for i in range(len(eval_dict))]
            losses.sort()
            losses_av = np.nanmean(losses)
            row = [f'{structure}']+[f'{attack_type}'] + [acc_av] + [losses_av]
            rows.append(row)
    else:
        for (structure, attack_type), acc_dict in results.items():
            accs = [acc_dict.get(f'acc_0', np.nan)]
            losses = [acc_dict.get(f'loss_0', np.nan)]
            row = [f'{structure}']+[f'{attack_type}'] + accs + losses
            rows.append(row)

    return pd.DataFrame(rows, columns=['model','attack_type', 'acc_av', 'loss_av'])

def make_row(structure : str,attack_and_model_type : str, model : keras.Model,
             idx : int = 0, results : dict = {},
             x = x_test, name_of_testing_sample : str = 'Original',
             y = y_test.reshape(-1),
            verbose = 1):
    key = (structure, attack_and_model_type)
    loss, acc = model.evaluate(x, y, verbose = verbose)
    
    if key not in results:
        results[key] = {}
    results[key][f'acc_{idx}_on_{name_of_testing_sample}'] = acc
    if name_of_testing_sample == 'Original':
        results[key][f'loss_{idx}_on_Original'] = loss
    else:
        pass
    return results

# %% [markdown]
# ### $M_{D\sqcup \widetilde{D}}$
#
# $\widetilde{D} \in \{\textrm{untargeted PGD}, \textrm{targeted PGD}, \textrm{CWL2}\}$

# %%
folder = 'adversarial_models/full_and_fine/'
pattern = os.path.join(folder, '*.keras')
file_list = sorted(glob.glob(pattern))
loaded_models= {os.path.basename(f): load_model(f) for f in file_list}

results = {}  # structure: {(structure, attack type): [acc_0, acc_1, acc_2, acc_3]}

for filename, model in loaded_models.items():
    # Example filename: 'ResNet20v1_ff_untargeted-adv_0.keras'
    # Extract family and index
    base = filename.replace('.keras','')
    parts = base.split('_')
    structure = parts[0]  # ResNet20v1, etc.
    attack_and_model_type = parts[2] + '_ff' 
    idx = int(parts[-1].split('-')[-1])  # last digit after -adv_

    results = make_row(structure, attack_and_model_type, model, 
            idx = idx,results = results,
                      y = y_test_categorical_20)

df = make_df(results)
df.to_csv('results/result_full_and_fine_testing_original.csv')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.3413 - acc: 0.7100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.6509 - acc: 0.6449
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4803 - acc: 0.6960
# 313/313 [==============================] - 1s 2ms/step - loss: 1.1859 - acc: 0.7339
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8025 - acc: 0.8452
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8304 - acc: 0.8357
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6017 - acc: 0.8722
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5952 - acc: 0.8691
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6917 - acc: 0.8556
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8042 - acc: 0.8386
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6038 - acc: 0.8760
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7187 - acc: 0.8519
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4392 - acc: 0.6989
# 313/313 [==============================] - 1s 3ms/step - loss: 1.2787 - acc: 0.7021
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0317 - acc: 0.7710
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1350 - acc: 0.7478
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8631 - acc: 0.8225
# 313/313 [==============================] - 1s 3ms/step - loss: 1.0139 - acc: 0.7951
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8570 - acc: 0.8240
# 313/313 [==============================] - 3s 2ms/step - loss: 0.7693 - acc: 0.8366
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8823 - acc: 0.7979
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9711 - acc: 0.7940
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8638 - acc: 0.8147
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8815 - acc: 0.8118
# 313/313 [==============================] - 2s 4ms/step - loss: 1.2029 - acc: 0.7520
# 313/313 [==============================] - 2s 4ms/step - loss: 1.4967 - acc: 0.7192
# 313/313 [==============================] - 2s 4ms/step - loss: 1.1256 - acc: 0.7656
# 313/313 [==============================] - 2s 4ms/step - loss: 1.3717 - acc: 0.7252
# 313/313 [==============================] - 2s 4ms/step - loss: 0.9756 - acc: 0.8145
# 313/313 [==============================] - 2s 4ms/step - loss: 0.9855 - acc: 0.8251
# 313/313 [==============================] - 2s 4ms/step - loss: 0.8372 - acc: 0.8538
# 313/313 [==============================] - 2s 4ms/step - loss: 0.6779 - acc: 0.8682
# 313/313 [==============================] - 2s 4ms/step - loss: 0.7724 - acc: 0.8510
# 313/313 [==============================] - 2s 4ms/step - loss: 0.9030 - acc: 0.8290
# 313/313 [==============================] - 2s 4ms/step - loss: 0.8001 - acc: 0.8410
# 313/313 [==============================] - 2s 4ms/step - loss: 0.8757 - acc: 0.8340
# 313/313 [==============================] - 2s 5ms/step - loss: 1.0530 - acc: 0.7614
# 313/313 [==============================] - 3s 5ms/step - loss: 1.0952 - acc: 0.7563
# 313/313 [==============================] - 3s 6ms/step - loss: 0.9957 - acc: 0.7866
# 313/313 [==============================] - 3s 6ms/step - loss: 1.0693 - acc: 0.7617
# 313/313 [==============================] - 3s 6ms/step - loss: 1.3287 - acc: 0.7461
# 313/313 [==============================] - 3s 6ms/step - loss: 0.7542 - acc: 0.8369
# 313/313 [==============================] - 3s 6ms/step - loss: 0.8530 - acc: 0.8234
# 313/313 [==============================] - 3s 6ms/step - loss: 0.9742 - acc: 0.8043
# 313/313 [==============================] - 3s 5ms/step - loss: 0.8596 - acc: 0.7930
# 313/313 [==============================] - 3s 6ms/step - loss: 0.8698 - acc: 0.8220
# 313/313 [==============================] - 3s 6ms/step - loss: 0.9458 - acc: 0.8071
# 313/313 [==============================] - 2s 5ms/step - loss: 0.9614 - acc: 0.7914

# %%
df
# Out:
#          model        attack_type    acc_av   loss_av
# 0   ResNet20v1          cw-adv_ff  0.696200  1.414593
# 1   ResNet20v1    targeted-adv_ff  0.855550  0.707468
# 2   ResNet20v1  untargeted-adv_ff  0.855525  0.704581
# 3   ResNet20v2          cw-adv_ff  0.729950  1.221137
# 4   ResNet20v2    targeted-adv_ff  0.819550  0.875817
# 5   ResNet20v2  untargeted-adv_ff  0.804600  0.899692
# 6   ResNet56v1          cw-adv_ff  0.740500  1.299252
# 7   ResNet56v1    targeted-adv_ff  0.840400  0.869057
# 8   ResNet56v1  untargeted-adv_ff  0.838750  0.837809
# 9   ResNet56v2          cw-adv_ff  0.766500  1.053291
# 10  ResNet56v2    targeted-adv_ff  0.802675  0.977530
# 11  ResNet56v2  untargeted-adv_ff  0.803375  0.909158

# %% [markdown]
# ### $\widetilde{M}_{D\sqcup \widetilde{D}}$
#
# $\widetilde{D} \in \{\textrm{untargeted PGD}, \textrm{targeted PGD}, \textrm{CWL2}\}$

# %%
folder = 'adversarial_models/specialized_from_full_and_fine/'
pattern = os.path.join(folder, '*.keras')
file_list = sorted(glob.glob(pattern))
loaded_models= {os.path.basename(f): load_model(f) for f in file_list}

results = {}  # structure: {(structure, attack type): [acc_0, acc_1, acc_2, acc_3]}

for filename, model in loaded_models.items():
    # Example filename: 'classifying_original_from_ResNet20v1_ff_cw-adv_0.keras'
    # Extract family and index
    base = filename.replace('.keras','')
    parts = base.split('_')
    structure = parts[3]  # ResNet20v1, etc.
    attack_and_model_type = parts[5] + '_experts'
    idx = int(parts[-1].split('-')[-1])  # last digit after -adv_

    results = make_row(structure, attack_and_model_type, model, 
            idx = idx,results = results,
                      y = y_test_categorical_10)

df = make_df(results)
df.to_csv('results/result_specialized_from_ff_testing_original.csv')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5018 - accuracy: 0.9034
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4999 - accuracy: 0.9022
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5235 - accuracy: 0.9023
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5058 - accuracy: 0.9047
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5091 - accuracy: 0.8978
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4905 - accuracy: 0.9035
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4784 - accuracy: 0.9044
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4570 - accuracy: 0.9061
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4900 - accuracy: 0.9029
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5046 - accuracy: 0.8991
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5138 - accuracy: 0.9009
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4851 - accuracy: 0.9034
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4979 - accuracy: 0.9051
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5008 - accuracy: 0.9069
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5025 - accuracy: 0.9060
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5034 - accuracy: 0.9059
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4740 - accuracy: 0.9097
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4731 - accuracy: 0.9081
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4674 - accuracy: 0.9083
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4789 - accuracy: 0.9071
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4757 - accuracy: 0.9101
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4744 - accuracy: 0.9060
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4829 - accuracy: 0.9058
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4873 - accuracy: 0.9052
# 313/313 [==============================] - 2s 4ms/step - loss: 0.5085 - accuracy: 0.9131
# 313/313 [==============================] - 2s 4ms/step - loss: 0.5123 - accuracy: 0.9100
# 313/313 [==============================] - 2s 4ms/step - loss: 0.5163 - accuracy: 0.9115
# 313/313 [==============================] - 2s 4ms/step - loss: 0.5149 - accuracy: 0.9122
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4849 - accuracy: 0.9059
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4685 - accuracy: 0.9112
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4826 - accuracy: 0.9090
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4910 - accuracy: 0.9102
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4598 - accuracy: 0.9096
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4840 - accuracy: 0.9097
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4846 - accuracy: 0.9078
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4681 - accuracy: 0.9123
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4916 - accuracy: 0.9156
# 313/313 [==============================] - 3s 6ms/step - loss: 0.4794 - accuracy: 0.9152
# 313/313 [==============================] - 3s 6ms/step - loss: 0.4596 - accuracy: 0.9135
# 313/313 [==============================] - 3s 6ms/step - loss: 0.5014 - accuracy: 0.9141
# 313/313 [==============================] - 3s 5ms/step - loss: 0.4605 - accuracy: 0.9127
# 313/313 [==============================] - 3s 5ms/step - loss: 0.4491 - accuracy: 0.9140
# 313/313 [==============================] - 3s 6ms/step - loss: 0.4583 - accuracy: 0.9136
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4481 - accuracy: 0.9125
# 313/313 [==============================] - 2s 5ms/step - loss: 0.5023 - accuracy: 0.9102
# 313/313 [==============================] - 3s 6ms/step - loss: 0.4493 - accuracy: 0.9128
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4281 - accuracy: 0.9112
# 313/313 [==============================] - 6s 6ms/step - loss: 0.4349 - accuracy: 0.9118

# %%
df
# Out:
#          model             attack_type    acc_av   loss_av
# 0   ResNet20v1          cw-adv_experts  0.903150  0.507745
# 1   ResNet20v1    targeted-adv_experts  0.902950  0.483714
# 2   ResNet20v1  untargeted-adv_experts  0.901575  0.498358
# 3   ResNet20v2          cw-adv_experts  0.905975  0.501167
# 4   ResNet20v2    targeted-adv_experts  0.908300  0.473372
# 5   ResNet20v2  untargeted-adv_experts  0.906775  0.480066
# 6   ResNet56v1          cw-adv_experts  0.911700  0.513016
# 7   ResNet56v1    targeted-adv_experts  0.909075  0.481757
# 8   ResNet56v1  untargeted-adv_experts  0.909850  0.474145
# 9   ResNet56v2          cw-adv_experts  0.914600  0.483012
# 10  ResNet56v2    targeted-adv_experts  0.913200  0.453999
# 11  ResNet56v2  untargeted-adv_experts  0.911500  0.453646

# %% [markdown]
# ### $M_{D\cup \widetilde{D}}$ and $\widetilde{M}_{D\cup \widetilde{D}}$
#
#
# $\widetilde{D} \in \{\textrm{untargeted PGD}, \textrm{targeted PGD}, \textrm{CWL2}\}$

# %%
folder = 'adversarial_models/naive_method/'
pattern = os.path.join(folder, '*.keras')
file_list = sorted(glob.glob(pattern))
loaded_models= {os.path.basename(f): load_model(f) for f in file_list}

results_naive = {}  
results_fine = {}
for filename, model in loaded_models.items():
    # Example filename: 'ResNet20v1_naive_untargeted.keras'
    # or 'ResNet20v1_naive_untargeted_fine.keras'
    # Extract family and index
    base = filename.replace('.keras','')
    parts = base.split('_')
    structure = parts[0]  # ResNet20v1, etc.
    if parts[-1] == 'fine':
        attack_and_model_type = parts[-2] + '_naive_specialized_once'
        results_fine = make_row(structure, attack_and_model_type, model, 
    #             idx = idx,
                           results = results_fine,
                          y = y_test_categorical_10)
    else:
        attack_and_model_type = parts[-1] + '_naive'
    #     idx = int(parts[-1].split('-')[-1])  # last digit after -adv_

        results_naive = make_row(structure, attack_and_model_type, model, 
    #             idx = idx,
                           results = results_naive,
                          y = y_test_categorical_10)

df_naive = make_df(results_naive)
df_naive_fine = make_df(results_fine)
df_naive.to_csv('results/result_naive_testing_original.csv')
df_naive_fine.to_csv('results/result_naive_fine_testing_original.csv')
df_naive
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7770 - acc: 0.8480
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4576 - accuracy: 0.9073
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8285 - acc: 0.8424
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4699 - accuracy: 0.9016
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9653 - acc: 0.8232
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4733 - accuracy: 0.9051
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8728 - acc: 0.8146
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4927 - accuracy: 0.9070
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0543 - acc: 0.7994
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4800 - accuracy: 0.9016
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9453 - acc: 0.8040
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4734 - accuracy: 0.9069
# 313/313 [==============================] - 2s 4ms/step - loss: 0.6628 - acc: 0.8807
# 313/313 [==============================] - 2s 4ms/step - loss: 0.5124 - accuracy: 0.9108
# 313/313 [==============================] - 2s 4ms/step - loss: 0.8908 - acc: 0.8437
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4986 - accuracy: 0.9074
# 313/313 [==============================] - 2s 4ms/step - loss: 0.8090 - acc: 0.8513
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4771 - accuracy: 0.9056
# 313/313 [==============================] - 2s 5ms/step - loss: 0.8766 - acc: 0.8171
# 313/313 [==============================] - 3s 6ms/step - loss: 0.4357 - accuracy: 0.9176
# 313/313 [==============================] - 3s 6ms/step - loss: 0.8786 - acc: 0.8295
# 313/313 [==============================] - 3s 6ms/step - loss: 0.4615 - accuracy: 0.9130
# 313/313 [==============================] - 3s 6ms/step - loss: 0.8388 - acc: 0.8172
# 313/313 [==============================] - 3s 6ms/step - loss: 0.4436 - accuracy: 0.9101
#          model       attack_type  acc_av   loss_av
# 0   ResNet20v1          cw_naive  0.8480  0.776990
# 1   ResNet20v1    targeted_naive  0.8424  0.828501
# 2   ResNet20v1  untargeted_naive  0.8232  0.965299
# 3   ResNet20v2          cw_naive  0.8146  0.872845
# 4   ResNet20v2    targeted_naive  0.7994  1.054251
# 5   ResNet20v2  untargeted_naive  0.8040  0.945313
# 6   ResNet56v1          cw_naive  0.8807  0.662840
# 7   ResNet56v1    targeted_naive  0.8437  0.890810
# 8   ResNet56v1  untargeted_naive  0.8513  0.808957
# 9   ResNet56v2          cw_naive  0.8171  0.876579
# 10  ResNet56v2    targeted_naive  0.8295  0.878647
# 11  ResNet56v2  untargeted_naive  0.8172  0.838849

# %%
df_naive_fine
# Out:
#          model                        attack_type  acc_av   loss_av
# 0   ResNet20v1          cw_naive_specialized_once  0.9073  0.457576
# 1   ResNet20v1    targeted_naive_specialized_once  0.9016  0.469850
# 2   ResNet20v1  untargeted_naive_specialized_once  0.9051  0.473326
# 3   ResNet20v2          cw_naive_specialized_once  0.9070  0.492664
# 4   ResNet20v2    targeted_naive_specialized_once  0.9016  0.479983
# 5   ResNet20v2  untargeted_naive_specialized_once  0.9069  0.473368
# 6   ResNet56v1          cw_naive_specialized_once  0.9108  0.512450
# 7   ResNet56v1    targeted_naive_specialized_once  0.9074  0.498648
# 8   ResNet56v1  untargeted_naive_specialized_once  0.9056  0.477092
# 9   ResNet56v2          cw_naive_specialized_once  0.9176  0.435703
# 10  ResNet56v2    targeted_naive_specialized_once  0.9130  0.461499
# 11  ResNet56v2  untargeted_naive_specialized_once  0.9101  0.443555

# %% [markdown]
# ### Standard CIFAR10 models and its specialization (once) on original testing dataset

# %%
folder = 'CIFAR10models/ResNet/'
pattern = os.path.join(folder, '*cifar10*.keras')
file_list = sorted(glob.glob(pattern))
loaded_models= {os.path.basename(f): load_model(f) for f in file_list}

results = {}  

for filename, model in loaded_models.items():
    # Example filename: 'n_3_v1_cifar10_2.keras'
    # Extract family and index
    base = filename.replace('.keras','')
    parts = base.split('_')
    structure = label_dict[(int(parts[1]),int(parts[2][-1]))]  # ResNet20v1, etc.
    attack_and_model_type = 'Standard'
    idx = int(parts[-1][-1])  # possibly cifar10 -> 0

    results = make_row(structure, attack_and_model_type, model, 
            idx = idx,results = results,
                      y = y_test_categorical_10)

df = make_df(results)
df.to_csv('results/result_standard-models_testing_original.csv')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8895 - acc: 0.8248
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7318 - acc: 0.8520
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7270 - acc: 0.8534
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6726 - acc: 0.8592
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6899 - acc: 0.8485
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6850 - acc: 0.8600
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7611 - acc: 0.8439
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8633 - acc: 0.8251
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7913 - acc: 0.8208
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8953 - acc: 0.8017
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8631 - acc: 0.8126
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8325 - acc: 0.8167
# 313/313 [==============================] - 2s 4ms/step - loss: 0.6225 - acc: 0.8785
# 313/313 [==============================] - 2s 4ms/step - loss: 0.8104 - acc: 0.8445
# 313/313 [==============================] - 2s 4ms/step - loss: 0.7486 - acc: 0.8575
# 313/313 [==============================] - 2s 4ms/step - loss: 0.8250 - acc: 0.8486
# 313/313 [==============================] - 2s 5ms/step - loss: 0.7925 - acc: 0.8218
# 313/313 [==============================] - 2s 5ms/step - loss: 0.7674 - acc: 0.8355
# 313/313 [==============================] - 3s 5ms/step - loss: 0.8944 - acc: 0.8065
# 313/313 [==============================] - 2s 5ms/step - loss: 0.8390 - acc: 0.8241

# %%
folder = 'CIFAR10models/more_tunned/'
pattern = os.path.join(folder, '*.keras')
file_list = sorted(glob.glob(pattern))
loaded_models= {os.path.basename(f): load_model(f) for f in file_list}

results = {}  

for filename, model in loaded_models.items():
    # Example filename: 'ResNet20v1_more_specialized_1.keras'
    # Extract family and index
    base = filename.replace('.keras','')
    parts = base.split('_')
    if parts[1] != 'more':
        continue
    structure = parts[0]  # ResNet20v1, etc.
    attack_and_model_type = 'once_specialized_from_standard'
    idx = int(parts[-1])  

    results = make_row(structure, attack_and_model_type, model, 
            idx = idx,results = results,
                      y = y_test_categorical_10)

df = make_df(results)
df.to_csv('results/result_once_specialized_from_standard-models_testing_original.csv')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4866 - accuracy: 0.9052
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4875 - accuracy: 0.9070
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4787 - accuracy: 0.9093
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4963 - accuracy: 0.9027
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5119 - accuracy: 0.9041
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5055 - accuracy: 0.9004
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4930 - accuracy: 0.9041
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4906 - accuracy: 0.9059
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4627 - accuracy: 0.9101
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5030 - accuracy: 0.9061
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4628 - accuracy: 0.9095
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4995 - accuracy: 0.9068
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4911 - accuracy: 0.9113
# 313/313 [==============================] - 2s 4ms/step - loss: 0.5133 - accuracy: 0.9096
# 313/313 [==============================] - 2s 4ms/step - loss: 0.5202 - accuracy: 0.9069
# 313/313 [==============================] - 2s 4ms/step - loss: 0.5010 - accuracy: 0.9128
# 313/313 [==============================] - 3s 6ms/step - loss: 0.4339 - accuracy: 0.9203
# 313/313 [==============================] - 3s 5ms/step - loss: 0.4609 - accuracy: 0.9174
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4698 - accuracy: 0.9109
# 313/313 [==============================] - 3s 5ms/step - loss: 0.4540 - accuracy: 0.9158

# %% [markdown]
# ## Testing on other dataset
#
# PGD type, targeted or untargeted, generated by resnet and vgg models
#
# cwl2 type, targeted or untargeted, generated by resnet models

# %%
## set all files.
## Possibly there is no merged testing dataset, or validation dataset.
## We only look for testing dataset.
import re

pattern1 = re.compile(r'_\d+to\d+_')
pattern2 = re.compile(r'test')

folder = './adversarial_examples/gen_by_ResNet'
all_files = os.listdir(folder)

filtered_files = [
    fname for fname in all_files
    if fname.endswith('.npy') and not pattern1.search(fname) and pattern2.search(fname)
]

# %%
## load all the testing dataset
## including testing dataset generated by VGG
loaded_testing_dataset = {}
import re
for f in filtered_files:
    
    base = f.replace('.keras.npy','').replace('.npy','')
    parts = base.split('_')
    attack_type = parts[0]
    if attack_type == 'cwl2':
        direction = parts[3]
        if direction == 'targeted':
            direction = direction +'_'+ parts[5]
        if parts[-1].isdigit():
            idx = 1
        else:
            idx = 0
        model_type = 'ResNet56v1'
    else:
        
        direction = parts[4]
        if direction == 'target':
            if parts[6] == 'second':
                direction = 'targeted_2nd'
                model_type = 'ResNet56v1'
                
            else:
                direction = 'targeted_ll'
                model_type = label_dict[(int(parts[10]),
                                        int(parts[11][-1]))]
                idx = parts[-1][-1]
        else:
            direction = 'untargeted'
            model_type = label_dict[(int(parts[8]),
                                        int(parts[9][-1]))]
            idx = parts[-1][-1]
    key = (attack_type, direction, model_type, idx)
    loaded_testing_dataset[key] = np.load(os.path.join(folder, f))


folder = './adversarial_examples/gen_by_VGG'
all_files = os.listdir(folder)

filtered_files = [
    fname for fname in all_files
    if fname.endswith('.npy') and pattern2.search(fname)
]
for f in filtered_files:
    base = f.replace('.npy','')
    parts = base.split('_')
    attack_type = parts[0]
    direction = parts[4]
    if direction == 'target':
        direction = 'targeted_ll'
        model_type = parts[8]
        if parts[-1].isdigit():
            idx = int(parts[-1])
        else:
            idx = 4
    else:
        direction = 'untargeted'
        model_type = parts[6]
        if parts[-1].isdigit():
            idx = int(parts[-1])
        else:
            idx = 4
    key = (attack_type, direction, model_type, idx)
    loaded_testing_dataset[key] = np.load(os.path.join(folder, f))

# %%
def evaluate_model_on_datasets(model_id : tuple, model : keras.Model,  datasets : dict, 
                               y,
                               results : dict = {},
                               verbose=0):
    """
    model_id : tuple (structure, model type, adversarial dataset (if any. else none), index)
    datasets key: tuple (attack type, attack direction, generating model, index)
    results: nested dict to fill, key: (model_id, dataset_id)
    y : truth label
    """
    
    y = y
    for dataset_id, x in datasets.items():
        loss, acc = model.evaluate(x, y, verbose=verbose)
        print(dataset_id)
        results[(model_id, dataset_id)] = {'acc': acc, 'loss': loss}
        
    return results

def make_df(results):
    """
    results: dict with key: (model_id, dataset_id) -> {'acc': value, 'loss': value}
    Returns dataframe with models as rows, datasets as columns (acc or loss).
    """
    rows = []
    for (model_id, dataset_id), metrics in results.items():
        row = list(model_id) + list(dataset_id) + [metrics['acc'], metrics['loss']]
        rows.append(row)
    
    df = pd.DataFrame(rows, columns=['testing_model_structure', 'testing_model_type', 'testing_model_augmentation', 'testing_model_idx',
                                     'D_attack_type', 'D_attack_direction', 'D_generating_model', 'D_idx',
                                     'acc', 'loss'])
    return df

# %%
# List of folders and (optional) patterns to search for models
model_sources = [
    ('adversarial_models/full_and_fine/', '*.keras'),
    ('adversarial_models/specialized_from_full_and_fine/', '*.keras'),
    ('adversarial_models/naive_method/', '*.keras'),
    ('CIFAR10models/more_tunned/', '*.keras'),
    ('CIFAR10models/ResNet/', '*cifar10*.keras'),
]

# Initialize list of all found files
file_list = []

for folder, pattern in model_sources:
    full_pattern = os.path.join(folder, pattern)
    matched_files = sorted(glob.glob(full_pattern))
    file_list.extend(matched_files)

# # Load all models into dictionary: {filename: model}
# loaded_models = {os.path.basename(f): load_model(f) for f in file_list}

# %%
# %%time
loaded_models = {}
for f in file_list:
    base = os.path.basename(f)
    parts = base.replace('.keras','').split('_')
    if parts[0] == 'classifying':
        model_structure = parts[3]
        model_type = 'S-ff'
        augmented_by = parts[5].split('-')[0]
        idx = parts[-1]
        model_key = (model_structure, model_type, augmented_by, idx)

    elif parts[0] == 'n':
        model_structure = label_dict[(int(parts[1]),
                                    int(parts[2][-1]))]
        model_type = 'B'
        augmented_by = 'None'
        idx = parts[-1][-1]
        model_key = (model_structure, model_type, augmented_by, idx)
    else:
        model_structure = parts[0]
        if parts[1] == 'ff':
            model_type = 'ff'
            augmented_by = parts[2].split('-')[0]
            idx = parts[-1]
            model_key = (model_structure, model_type, augmented_by, idx)
            
        elif parts[1] == 'naive':
            if parts[-1] == 'fine':
                model_type = 'S-nai'
            else:
                model_type = 'nai'
            augemented_by = parts[2]
            idx = 0
            model_key = (model_structure, model_type, augmented_by, idx)
        else:
            if parts[1] == 'more':
                model_type = 'S-B'
                augmented_by = 'None'
                idx = parts[-1]
                model_key = (model_structure, model_type, augmented_by, idx)
            else:
                continue
    
    loaded_models[model_key]=load_model(f)
# Out:
# CPU times: user 1min 49s, sys: 3.99 s, total: 1min 53s
# Wall time: 2min 2s

# %%
loaded_testing_dataset[('original','original','original', '0')] = x_test

# %%
import pandas as pd
df1 = pd.read_csv('results/master_results1.csv')
df2 = pd.read_csv('results/master_results2.csv')
df3 = pd.read_csv('results/master_results3.csv')

# %%
df2.iloc[6286:]
# Out:
#      testing_model_structure testing_model_type testing_model_augmentation  \
# 6286              ResNet56v1                  B                       None
# 6287              ResNet56v1                  B                       None
# 6288              ResNet56v1                  B                       None
# 6289              ResNet56v1                  B                       None
# 6290              ResNet56v1                  B                       None
# 6291              ResNet56v1                  B                       None
# 6292              ResNet56v1                  B                       None
#
#       testing_model_idx D_attack_type D_attack_direction D_generating_model  \
# 6286                  2           pgd         untargeted         ResNet56v2
# 6287                  2           pgd        targeted_ll              vgg19
# 6288                  2           pgd         untargeted              vgg13
# 6289                  2           pgd        targeted_ll              vgg19
# 6290                  2           pgd         untargeted              vgg11
# 6291                  2           pgd         untargeted              vgg19
# 6292                  2           pgd         untargeted              vgg16
#
#       D_idx     acc      loss
# 6286      2  0.7847  1.813779
# 6287      1  0.5445  2.686844
# 6288      1  0.8212  1.480899
# 6289      0  0.5540  2.730550
# 6290      0  0.7974  1.338869
# 6291      2  0.8066  1.768321
# 6292      0  0.8145  1.842525

# %%
df3 = df3.iloc[52:]

# %%
df2
# Out:
#      testing_model_structure testing_model_type testing_model_augmentation  \
# 0                 ResNet20v1               S-ff                 untargeted
# 1                 ResNet20v1               S-ff                 untargeted
# 2                 ResNet20v1               S-ff                 untargeted
# 3                 ResNet20v1               S-ff                 untargeted
# 4                 ResNet20v1               S-ff                 untargeted
# ...                      ...                ...                        ...
# 6288              ResNet56v1                  B                       None
# 6289              ResNet56v1                  B                       None
# 6290              ResNet56v1                  B                       None
# 6291              ResNet56v1                  B                       None
# 6292              ResNet56v1                  B                       None
#
#       testing_model_idx D_attack_type D_attack_direction D_generating_model  \
# 0                     3          cwl2         untargeted         ResNet56v1
# 1                     3           pgd        targeted_ll         ResNet20v1
# 2                     3           pgd        targeted_ll         ResNet56v2
# 3                     3           pgd        targeted_ll         ResNet20v2
# 4                     3           pgd         untargeted         ResNet20v2
# ...                 ...           ...                ...                ...
# 6288                  2           pgd         untargeted              vgg13
# 6289                  2           pgd        targeted_ll              vgg19
# 6290                  2           pgd         untargeted              vgg11
# 6291                  2           pgd         untargeted              vgg19
# 6292                  2           pgd         untargeted              vgg16
#
#       D_idx     acc      loss
# 0         1  0.2595  9.254398
# 1         1  0.8405  0.717156
# 2         2  0.8386  0.751812
# 3         2  0.8230  0.809612
# 4         3  0.8743  0.670368
# ...     ...     ...       ...
# 6288      1  0.8212  1.480899
# 6289      0  0.5540  2.730550
# 6290      0  0.7974  1.338869
# 6291      2  0.8066  1.768321
# 6292      0  0.8145  1.842525
#
# [6293 rows x 10 columns]

# %%
df3
# Out:
#     testing_model_structure testing_model_type testing_model_augmentation  \
# 52               ResNet56v1                  B                       None
# 53               ResNet56v1                  B                       None
# 54               ResNet56v1                  B                       None
# 55               ResNet56v1                  B                       None
# 56               ResNet56v1                  B                       None
# ..                      ...                ...                        ...
# 469              ResNet56v2                  B                       None
# 470              ResNet56v2                  B                       None
# 471              ResNet56v2                  B                       None
# 472              ResNet56v2                  B                       None
# 473              ResNet56v2                  B                       None
#
#      testing_model_idx D_attack_type D_attack_direction D_generating_model  \
# 52                   2           pgd        targeted_ll              vgg16
# 53                   2           pgd         untargeted              vgg13
# 54                   2           pgd         untargeted              vgg16
# 55                   2           pgd        targeted_ll              vgg16
# 56                   2           pgd         untargeted              vgg16
# ..                 ...           ...                ...                ...
# 469                  3           pgd        targeted_ll              vgg13
# 470                  3           pgd         untargeted              vgg16
# 471                  3           pgd         untargeted              vgg19
# 472                  3           pgd        targeted_ll              vgg11
# 473                  3      original           original           original
#
#      D_idx     acc      loss
# 52       1  0.5496  2.555589
# 53       4  0.8237  1.464711
# 54       2  0.8092  1.852720
# 55       0  0.5573  2.532015
# 56       1  0.8046  1.935211
# ..     ...     ...       ...
# 469      0  0.5287  2.633854
# 470      4  0.7913  1.770648
# 471      0  0.8060  1.407976
# 472      0  0.6429  1.677405
# 473      0  0.8241  0.839025
#
# [422 rows x 10 columns]

# %%
df
# Out:
#     testing_model_structure testing_model_type testing_model_augmentation  \
# 0                ResNet20v1               S-ff                 untargeted
# 1                ResNet20v1               S-ff                 untargeted
# 2                ResNet20v1               S-ff                 untargeted
# 3                ResNet20v1               S-ff                 untargeted
# 4                ResNet20v1               S-ff                 untargeted
# ..                      ...                ...                        ...
# 469              ResNet56v2                  B                       None
# 470              ResNet56v2                  B                       None
# 471              ResNet56v2                  B                       None
# 472              ResNet56v2                  B                       None
# 473              ResNet56v2                  B                       None
#
#      testing_model_idx D_attack_type D_attack_direction D_generating_model  \
# 0                    3          cwl2         untargeted         ResNet56v1
# 1                    3           pgd        targeted_ll         ResNet20v1
# 2                    3           pgd        targeted_ll         ResNet56v2
# 3                    3           pgd        targeted_ll         ResNet20v2
# 4                    3           pgd         untargeted         ResNet20v2
# ..                 ...           ...                ...                ...
# 469                  3           pgd        targeted_ll              vgg13
# 470                  3           pgd         untargeted              vgg16
# 471                  3           pgd         untargeted              vgg19
# 472                  3           pgd        targeted_ll              vgg11
# 473                  3      original           original           original
#
#      D_idx     acc      loss
# 0        1  0.2595  9.254398
# 1        1  0.8405  0.717156
# 2        2  0.8386  0.751812
# 3        2  0.8230  0.809612
# 4        3  0.8743  0.670368
# ..     ...     ...       ...
# 469      0  0.5287  2.633854
# 470      4  0.7913  1.770648
# 471      0  0.8060  1.407976
# 472      0  0.6429  1.677405
# 473      0  0.8241  0.839025
#
# [6715 rows x 10 columns]

# %%
df_new = pd.read_csv('results/master_results23.csv')
df_new
# Out:
#      testing_model_structure testing_model_type testing_model_augmentation  \
# 0                 ResNet20v1               S-ff                 untargeted
# 1                 ResNet20v1               S-ff                 untargeted
# 2                 ResNet20v1               S-ff                 untargeted
# 3                 ResNet20v1               S-ff                 untargeted
# 4                 ResNet20v1               S-ff                 untargeted
# ...                      ...                ...                        ...
# 6710              ResNet56v2                  B                       None
# 6711              ResNet56v2                  B                       None
# 6712              ResNet56v2                  B                       None
# 6713              ResNet56v2                  B                       None
# 6714              ResNet56v2                  B                       None
#
#       testing_model_idx D_attack_type D_attack_direction D_generating_model  \
# 0                     3          cwl2         untargeted         ResNet56v1
# 1                     3           pgd        targeted_ll         ResNet20v1
# 2                     3           pgd        targeted_ll         ResNet56v2
# 3                     3           pgd        targeted_ll         ResNet20v2
# 4                     3           pgd         untargeted         ResNet20v2
# ...                 ...           ...                ...                ...
# 6710                  3           pgd        targeted_ll              vgg13
# 6711                  3           pgd         untargeted              vgg16
# 6712                  3           pgd         untargeted              vgg19
# 6713                  3           pgd        targeted_ll              vgg11
# 6714                  3      original           original           original
#
#       D_idx     acc      loss
# 0         1  0.2595  9.254398
# 1         1  0.8405  0.717156
# 2         2  0.8386  0.751812
# 3         2  0.8230  0.809612
# 4         3  0.8743  0.670368
# ...     ...     ...       ...
# 6710      0  0.5287  2.633854
# 6711      4  0.7913  1.770648
# 6712      0  0.8060  1.407976
# 6713      0  0.6429  1.677405
# 6714      0  0.8241  0.839025
#
# [6715 rows x 10 columns]

# %%
condition = ((df['testing_model_structure'] == 'ResNet20v1')
            &(df['testing_model_type'] == 'S-ff')
            &(df['testing_model_augmentation'] == 'untargeted')
            &(df['testing_model_idx'] == 3))

# %%
df1 = df.iloc[:4661]

# %%
df1.to_csv('results/master_results1.csv', index=False)

# %%
results = {}
y = y_test_categorical_10
for model_key, m in loaded_models.items():
    if model_key in [('ResNet56v1', 'B', 'None', '2'),
('ResNet56v1', 'B', 'None', '3'),
('ResNet56v2', 'B', 'None', '0'),
('ResNet56v2', 'B', 'None', '1'),
('ResNet56v2', 'B', 'None', '2'),
('ResNet56v2', 'B', 'None', '3')]:
        
        print(model_key)
        results = evaluate_model_on_datasets(model_key, m, loaded_testing_dataset, y,
                                            verbose = 0, results = results)
# Out:
# ('ResNet56v1', 'B', 'None', '2')
# ('cwl2', 'untargeted', 'ResNet56v1', 1)
# ('pgd', 'targeted_ll', 'ResNet20v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '2')
# ('pgd', 'targeted_ll', 'ResNet20v2', '2')
# ('pgd', 'untargeted', 'ResNet20v2', '3')
# ('pgd', 'targeted_ll', 'ResNet20v1', '0')
# ('pgd', 'untargeted', 'ResNet56v2', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '1')
# ('pgd', 'targeted_ll', 'ResNet20v1', '6')
# ('pgd', 'untargeted', 'ResNet20v1', '5')
# ('pgd', 'untargeted', 'ResNet56v2', '3')
# ('pgd', 'untargeted', 'ResNet20v2', '2')
# ('pgd', 'targeted_ll', 'ResNet56v1', '3')
# ('pgd', 'targeted_ll', 'ResNet56v2', '3')
# ('pgd', 'targeted_ll', 'ResNet20v2', '3')
# ('pgd', 'untargeted', 'ResNet20v2', '1')
# ('pgd', 'targeted_ll', 'ResNet56v1', '1')
# ('pgd', 'untargeted', 'ResNet56v1', '3')
# ('pgd', 'untargeted', 'ResNet20v1', '7')
# ('pgd', 'targeted_2nd', 'ResNet56v1', '7')
# ('pgd', 'untargeted', 'ResNet20v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v1', '2')
# ('pgd', 'untargeted', 'ResNet56v1', '2')
# ('pgd', 'targeted_ll', 'ResNet20v2', '1')
# ('pgd', 'targeted_ll', 'ResNet20v2', '0')
# ('pgd', 'untargeted', 'ResNet56v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '5')
# ('pgd', 'targeted_ll', 'ResNet56v1', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '2')
# ('pgd', 'untargeted', 'ResNet20v2', '0')
# ('pgd', 'untargeted', 'ResNet20v1', '6')
# ('pgd', 'targeted_ll', 'ResNet20v1', '4')
# ('cwl2', 'targeted_2nd', 'ResNet56v1', 0)
# ('cwl2', 'targeted_ll', 'ResNet56v1', 0)
# ('pgd', 'untargeted', 'ResNet20v1', '4')
# ('pgd', 'untargeted', 'ResNet56v2', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '3')
# ('pgd', 'targeted_ll', 'ResNet20v1', '7')
# ('cwl2', 'targeted_ll', 'ResNet56v1', 1)
# ('pgd', 'untargeted', 'ResNet20v1', '0')
# ('pgd', 'untargeted', 'ResNet56v1', '0')
# ('pgd', 'untargeted', 'ResNet20v1', '3')
# ('pgd', 'untargeted', 'ResNet20v1', '2')
# ('cwl2', 'untargeted', 'ResNet56v1', 0)
# ('pgd', 'untargeted', 'ResNet56v2', '2')
# ('pgd', 'targeted_ll', 'vgg19', 1)
# ('pgd', 'untargeted', 'vgg13', 1)
# ('pgd', 'targeted_ll', 'vgg19', 0)
# ('pgd', 'untargeted', 'vgg11', 0)
# ('pgd', 'untargeted', 'vgg19', 2)
# ('pgd', 'untargeted', 'vgg16', 0)
# ('pgd', 'targeted_ll', 'vgg16', 1)
# ('pgd', 'untargeted', 'vgg13', 4)
# ('pgd', 'untargeted', 'vgg16', 2)
# ('pgd', 'targeted_ll', 'vgg16', 0)
# ('pgd', 'untargeted', 'vgg16', 1)
# ('pgd', 'targeted_ll', 'vgg16', 2)
# ('pgd', 'untargeted', 'vgg11', 4)
# ('pgd', 'targeted_ll', 'vgg11', 1)
# ('pgd', 'targeted_ll', 'vgg19', 2)
# ('pgd', 'targeted_ll', 'vgg13', 4)
# ('pgd', 'untargeted', 'vgg19', 4)
# ('pgd', 'targeted_ll', 'vgg13', 1)
# ('pgd', 'targeted_ll', 'vgg13', 2)
# ('pgd', 'targeted_ll', 'vgg19', 4)
# ('pgd', 'untargeted', 'vgg11', 2)
# ('pgd', 'targeted_ll', 'vgg11', 2)
# ('pgd', 'targeted_ll', 'vgg16', 4)
# ('pgd', 'untargeted', 'vgg13', 0)
# ('pgd', 'targeted_ll', 'vgg11', 4)
# ('pgd', 'untargeted', 'vgg13', 2)
# ('pgd', 'untargeted', 'vgg11', 1)
# ('pgd', 'untargeted', 'vgg19', 1)
# ('pgd', 'targeted_ll', 'vgg13', 0)
# ('pgd', 'untargeted', 'vgg16', 4)
# ('pgd', 'untargeted', 'vgg19', 0)
# ('pgd', 'targeted_ll', 'vgg11', 0)
# ('original', 'original', 'original', '0')
# ('ResNet56v1', 'B', 'None', '3')
# ('cwl2', 'untargeted', 'ResNet56v1', 1)
# ('pgd', 'targeted_ll', 'ResNet20v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '2')
# ('pgd', 'targeted_ll', 'ResNet20v2', '2')
# ('pgd', 'untargeted', 'ResNet20v2', '3')
# ('pgd', 'targeted_ll', 'ResNet20v1', '0')
# ('pgd', 'untargeted', 'ResNet56v2', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '1')
# ('pgd', 'targeted_ll', 'ResNet20v1', '6')
# ('pgd', 'untargeted', 'ResNet20v1', '5')
# ('pgd', 'untargeted', 'ResNet56v2', '3')
# ('pgd', 'untargeted', 'ResNet20v2', '2')
# ('pgd', 'targeted_ll', 'ResNet56v1', '3')
# ('pgd', 'targeted_ll', 'ResNet56v2', '3')
# ('pgd', 'targeted_ll', 'ResNet20v2', '3')
# ('pgd', 'untargeted', 'ResNet20v2', '1')
# ('pgd', 'targeted_ll', 'ResNet56v1', '1')
# ('pgd', 'untargeted', 'ResNet56v1', '3')
# ('pgd', 'untargeted', 'ResNet20v1', '7')
# ('pgd', 'targeted_2nd', 'ResNet56v1', '7')
# ('pgd', 'untargeted', 'ResNet20v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v1', '2')
# ('pgd', 'untargeted', 'ResNet56v1', '2')
# ('pgd', 'targeted_ll', 'ResNet20v2', '1')
# ('pgd', 'targeted_ll', 'ResNet20v2', '0')
# ('pgd', 'untargeted', 'ResNet56v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '5')
# ('pgd', 'targeted_ll', 'ResNet56v1', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '2')
# ('pgd', 'untargeted', 'ResNet20v2', '0')
# ('pgd', 'untargeted', 'ResNet20v1', '6')
# ('pgd', 'targeted_ll', 'ResNet20v1', '4')
# ('cwl2', 'targeted_2nd', 'ResNet56v1', 0)
# ('cwl2', 'targeted_ll', 'ResNet56v1', 0)
# ('pgd', 'untargeted', 'ResNet20v1', '4')
# ('pgd', 'untargeted', 'ResNet56v2', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '3')
# ('pgd', 'targeted_ll', 'ResNet20v1', '7')
# ('cwl2', 'targeted_ll', 'ResNet56v1', 1)
# ('pgd', 'untargeted', 'ResNet20v1', '0')
# ('pgd', 'untargeted', 'ResNet56v1', '0')
# ('pgd', 'untargeted', 'ResNet20v1', '3')
# ('pgd', 'untargeted', 'ResNet20v1', '2')
# ('cwl2', 'untargeted', 'ResNet56v1', 0)
# ('pgd', 'untargeted', 'ResNet56v2', '2')
# ('pgd', 'targeted_ll', 'vgg19', 1)
# ('pgd', 'untargeted', 'vgg13', 1)
# ('pgd', 'targeted_ll', 'vgg19', 0)
# ('pgd', 'untargeted', 'vgg11', 0)
# ('pgd', 'untargeted', 'vgg19', 2)
# ('pgd', 'untargeted', 'vgg16', 0)
# ('pgd', 'targeted_ll', 'vgg16', 1)
# ('pgd', 'untargeted', 'vgg13', 4)
# ('pgd', 'untargeted', 'vgg16', 2)
# ('pgd', 'targeted_ll', 'vgg16', 0)
# ('pgd', 'untargeted', 'vgg16', 1)
# ('pgd', 'targeted_ll', 'vgg16', 2)
# ('pgd', 'untargeted', 'vgg11', 4)
# ('pgd', 'targeted_ll', 'vgg11', 1)
# ('pgd', 'targeted_ll', 'vgg19', 2)
# ('pgd', 'targeted_ll', 'vgg13', 4)
# ('pgd', 'untargeted', 'vgg19', 4)
# ('pgd', 'targeted_ll', 'vgg13', 1)
# ('pgd', 'targeted_ll', 'vgg13', 2)
# ('pgd', 'targeted_ll', 'vgg19', 4)
# ('pgd', 'untargeted', 'vgg11', 2)
# ('pgd', 'targeted_ll', 'vgg11', 2)
# ('pgd', 'targeted_ll', 'vgg16', 4)
# ('pgd', 'untargeted', 'vgg13', 0)
# ('pgd', 'targeted_ll', 'vgg11', 4)
# ('pgd', 'untargeted', 'vgg13', 2)
# ('pgd', 'untargeted', 'vgg11', 1)
# ('pgd', 'untargeted', 'vgg19', 1)
# ('pgd', 'targeted_ll', 'vgg13', 0)
# ('pgd', 'untargeted', 'vgg16', 4)
# ('pgd', 'untargeted', 'vgg19', 0)
# ('pgd', 'targeted_ll', 'vgg11', 0)
# ('original', 'original', 'original', '0')
# ('ResNet56v2', 'B', 'None', '0')
# ('cwl2', 'untargeted', 'ResNet56v1', 1)
# ('pgd', 'targeted_ll', 'ResNet20v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '2')
# ('pgd', 'targeted_ll', 'ResNet20v2', '2')
# ('pgd', 'untargeted', 'ResNet20v2', '3')
# ('pgd', 'targeted_ll', 'ResNet20v1', '0')
# ('pgd', 'untargeted', 'ResNet56v2', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '1')
# ('pgd', 'targeted_ll', 'ResNet20v1', '6')
# ('pgd', 'untargeted', 'ResNet20v1', '5')
# ('pgd', 'untargeted', 'ResNet56v2', '3')
# ('pgd', 'untargeted', 'ResNet20v2', '2')
# ('pgd', 'targeted_ll', 'ResNet56v1', '3')
# ('pgd', 'targeted_ll', 'ResNet56v2', '3')
# ('pgd', 'targeted_ll', 'ResNet20v2', '3')
# ('pgd', 'untargeted', 'ResNet20v2', '1')
# ('pgd', 'targeted_ll', 'ResNet56v1', '1')
# ('pgd', 'untargeted', 'ResNet56v1', '3')
# ('pgd', 'untargeted', 'ResNet20v1', '7')
# ('pgd', 'targeted_2nd', 'ResNet56v1', '7')
# ('pgd', 'untargeted', 'ResNet20v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v1', '2')
# ('pgd', 'untargeted', 'ResNet56v1', '2')
# ('pgd', 'targeted_ll', 'ResNet20v2', '1')
# ('pgd', 'targeted_ll', 'ResNet20v2', '0')
# ('pgd', 'untargeted', 'ResNet56v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '5')
# ('pgd', 'targeted_ll', 'ResNet56v1', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '2')
# ('pgd', 'untargeted', 'ResNet20v2', '0')
# ('pgd', 'untargeted', 'ResNet20v1', '6')
# ('pgd', 'targeted_ll', 'ResNet20v1', '4')
# ('cwl2', 'targeted_2nd', 'ResNet56v1', 0)
# ('cwl2', 'targeted_ll', 'ResNet56v1', 0)
# ('pgd', 'untargeted', 'ResNet20v1', '4')
# ('pgd', 'untargeted', 'ResNet56v2', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '3')
# ('pgd', 'targeted_ll', 'ResNet20v1', '7')
# ('cwl2', 'targeted_ll', 'ResNet56v1', 1)
# ('pgd', 'untargeted', 'ResNet20v1', '0')
# ('pgd', 'untargeted', 'ResNet56v1', '0')
# ('pgd', 'untargeted', 'ResNet20v1', '3')
# ('pgd', 'untargeted', 'ResNet20v1', '2')
# ('cwl2', 'untargeted', 'ResNet56v1', 0)
# ('pgd', 'untargeted', 'ResNet56v2', '2')
# ('pgd', 'targeted_ll', 'vgg19', 1)
# ('pgd', 'untargeted', 'vgg13', 1)
# ('pgd', 'targeted_ll', 'vgg19', 0)
# ('pgd', 'untargeted', 'vgg11', 0)
# ('pgd', 'untargeted', 'vgg19', 2)
# ('pgd', 'untargeted', 'vgg16', 0)
# ('pgd', 'targeted_ll', 'vgg16', 1)
# ('pgd', 'untargeted', 'vgg13', 4)
# ('pgd', 'untargeted', 'vgg16', 2)
# ('pgd', 'targeted_ll', 'vgg16', 0)
# ('pgd', 'untargeted', 'vgg16', 1)
# ('pgd', 'targeted_ll', 'vgg16', 2)
# ('pgd', 'untargeted', 'vgg11', 4)
# ('pgd', 'targeted_ll', 'vgg11', 1)
# ('pgd', 'targeted_ll', 'vgg19', 2)
# ('pgd', 'targeted_ll', 'vgg13', 4)
# ('pgd', 'untargeted', 'vgg19', 4)
# ('pgd', 'targeted_ll', 'vgg13', 1)
# ('pgd', 'targeted_ll', 'vgg13', 2)
# ('pgd', 'targeted_ll', 'vgg19', 4)
# ('pgd', 'untargeted', 'vgg11', 2)
# ('pgd', 'targeted_ll', 'vgg11', 2)
# ('pgd', 'targeted_ll', 'vgg16', 4)
# ('pgd', 'untargeted', 'vgg13', 0)
# ('pgd', 'targeted_ll', 'vgg11', 4)
# ('pgd', 'untargeted', 'vgg13', 2)
# ('pgd', 'untargeted', 'vgg11', 1)
# ('pgd', 'untargeted', 'vgg19', 1)
# ('pgd', 'targeted_ll', 'vgg13', 0)
# ('pgd', 'untargeted', 'vgg16', 4)
# ('pgd', 'untargeted', 'vgg19', 0)
# ('pgd', 'targeted_ll', 'vgg11', 0)
# ('original', 'original', 'original', '0')
# ('ResNet56v2', 'B', 'None', '1')
# ('cwl2', 'untargeted', 'ResNet56v1', 1)
# ('pgd', 'targeted_ll', 'ResNet20v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '2')
# ('pgd', 'targeted_ll', 'ResNet20v2', '2')
# ('pgd', 'untargeted', 'ResNet20v2', '3')
# ('pgd', 'targeted_ll', 'ResNet20v1', '0')
# ('pgd', 'untargeted', 'ResNet56v2', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '1')
# ('pgd', 'targeted_ll', 'ResNet20v1', '6')
# ('pgd', 'untargeted', 'ResNet20v1', '5')
# ('pgd', 'untargeted', 'ResNet56v2', '3')
# ('pgd', 'untargeted', 'ResNet20v2', '2')
# ('pgd', 'targeted_ll', 'ResNet56v1', '3')
# ('pgd', 'targeted_ll', 'ResNet56v2', '3')
# ('pgd', 'targeted_ll', 'ResNet20v2', '3')
# ('pgd', 'untargeted', 'ResNet20v2', '1')
# ('pgd', 'targeted_ll', 'ResNet56v1', '1')
# ('pgd', 'untargeted', 'ResNet56v1', '3')
# ('pgd', 'untargeted', 'ResNet20v1', '7')
# ('pgd', 'targeted_2nd', 'ResNet56v1', '7')
# ('pgd', 'untargeted', 'ResNet20v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v1', '2')
# ('pgd', 'untargeted', 'ResNet56v1', '2')
# ('pgd', 'targeted_ll', 'ResNet20v2', '1')
# ('pgd', 'targeted_ll', 'ResNet20v2', '0')
# ('pgd', 'untargeted', 'ResNet56v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '5')
# ('pgd', 'targeted_ll', 'ResNet56v1', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '2')
# ('pgd', 'untargeted', 'ResNet20v2', '0')
# ('pgd', 'untargeted', 'ResNet20v1', '6')
# ('pgd', 'targeted_ll', 'ResNet20v1', '4')
# ('cwl2', 'targeted_2nd', 'ResNet56v1', 0)
# ('cwl2', 'targeted_ll', 'ResNet56v1', 0)
# ('pgd', 'untargeted', 'ResNet20v1', '4')
# ('pgd', 'untargeted', 'ResNet56v2', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '3')
# ('pgd', 'targeted_ll', 'ResNet20v1', '7')
# ('cwl2', 'targeted_ll', 'ResNet56v1', 1)
# ('pgd', 'untargeted', 'ResNet20v1', '0')
# ('pgd', 'untargeted', 'ResNet56v1', '0')
# ('pgd', 'untargeted', 'ResNet20v1', '3')
# ('pgd', 'untargeted', 'ResNet20v1', '2')
# ('cwl2', 'untargeted', 'ResNet56v1', 0)
# ('pgd', 'untargeted', 'ResNet56v2', '2')
# ('pgd', 'targeted_ll', 'vgg19', 1)
# ('pgd', 'untargeted', 'vgg13', 1)
# ('pgd', 'targeted_ll', 'vgg19', 0)
# ('pgd', 'untargeted', 'vgg11', 0)
# ('pgd', 'untargeted', 'vgg19', 2)
# ('pgd', 'untargeted', 'vgg16', 0)
# ('pgd', 'targeted_ll', 'vgg16', 1)
# ('pgd', 'untargeted', 'vgg13', 4)
# ('pgd', 'untargeted', 'vgg16', 2)
# ('pgd', 'targeted_ll', 'vgg16', 0)
# ('pgd', 'untargeted', 'vgg16', 1)
# ('pgd', 'targeted_ll', 'vgg16', 2)
# ('pgd', 'untargeted', 'vgg11', 4)
# ('pgd', 'targeted_ll', 'vgg11', 1)
# ('pgd', 'targeted_ll', 'vgg19', 2)
# ('pgd', 'targeted_ll', 'vgg13', 4)
# ('pgd', 'untargeted', 'vgg19', 4)
# ('pgd', 'targeted_ll', 'vgg13', 1)
# ('pgd', 'targeted_ll', 'vgg13', 2)
# ('pgd', 'targeted_ll', 'vgg19', 4)
# ('pgd', 'untargeted', 'vgg11', 2)
# ('pgd', 'targeted_ll', 'vgg11', 2)
# ('pgd', 'targeted_ll', 'vgg16', 4)
# ('pgd', 'untargeted', 'vgg13', 0)
# ('pgd', 'targeted_ll', 'vgg11', 4)
# ('pgd', 'untargeted', 'vgg13', 2)
# ('pgd', 'untargeted', 'vgg11', 1)
# ('pgd', 'untargeted', 'vgg19', 1)
# ('pgd', 'targeted_ll', 'vgg13', 0)
# ('pgd', 'untargeted', 'vgg16', 4)
# ('pgd', 'untargeted', 'vgg19', 0)
# ('pgd', 'targeted_ll', 'vgg11', 0)
# ('original', 'original', 'original', '0')
# ('ResNet56v2', 'B', 'None', '2')
# ('cwl2', 'untargeted', 'ResNet56v1', 1)
# ('pgd', 'targeted_ll', 'ResNet20v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '2')
# ('pgd', 'targeted_ll', 'ResNet20v2', '2')
# ('pgd', 'untargeted', 'ResNet20v2', '3')
# ('pgd', 'targeted_ll', 'ResNet20v1', '0')
# ('pgd', 'untargeted', 'ResNet56v2', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '1')
# ('pgd', 'targeted_ll', 'ResNet20v1', '6')
# ('pgd', 'untargeted', 'ResNet20v1', '5')
# ('pgd', 'untargeted', 'ResNet56v2', '3')
# ('pgd', 'untargeted', 'ResNet20v2', '2')
# ('pgd', 'targeted_ll', 'ResNet56v1', '3')
# ('pgd', 'targeted_ll', 'ResNet56v2', '3')
# ('pgd', 'targeted_ll', 'ResNet20v2', '3')
# ('pgd', 'untargeted', 'ResNet20v2', '1')
# ('pgd', 'targeted_ll', 'ResNet56v1', '1')
# ('pgd', 'untargeted', 'ResNet56v1', '3')
# ('pgd', 'untargeted', 'ResNet20v1', '7')
# ('pgd', 'targeted_2nd', 'ResNet56v1', '7')
# ('pgd', 'untargeted', 'ResNet20v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v1', '2')
# ('pgd', 'untargeted', 'ResNet56v1', '2')
# ('pgd', 'targeted_ll', 'ResNet20v2', '1')
# ('pgd', 'targeted_ll', 'ResNet20v2', '0')
# ('pgd', 'untargeted', 'ResNet56v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '5')
# ('pgd', 'targeted_ll', 'ResNet56v1', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '2')
# ('pgd', 'untargeted', 'ResNet20v2', '0')
# ('pgd', 'untargeted', 'ResNet20v1', '6')
# ('pgd', 'targeted_ll', 'ResNet20v1', '4')
# ('cwl2', 'targeted_2nd', 'ResNet56v1', 0)
# ('cwl2', 'targeted_ll', 'ResNet56v1', 0)
# ('pgd', 'untargeted', 'ResNet20v1', '4')
# ('pgd', 'untargeted', 'ResNet56v2', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '3')
# ('pgd', 'targeted_ll', 'ResNet20v1', '7')
# ('cwl2', 'targeted_ll', 'ResNet56v1', 1)
# ('pgd', 'untargeted', 'ResNet20v1', '0')
# ('pgd', 'untargeted', 'ResNet56v1', '0')
# ('pgd', 'untargeted', 'ResNet20v1', '3')
# ('pgd', 'untargeted', 'ResNet20v1', '2')
# ('cwl2', 'untargeted', 'ResNet56v1', 0)
# ('pgd', 'untargeted', 'ResNet56v2', '2')
# ('pgd', 'targeted_ll', 'vgg19', 1)
# ('pgd', 'untargeted', 'vgg13', 1)
# ('pgd', 'targeted_ll', 'vgg19', 0)
# ('pgd', 'untargeted', 'vgg11', 0)
# ('pgd', 'untargeted', 'vgg19', 2)
# ('pgd', 'untargeted', 'vgg16', 0)
# ('pgd', 'targeted_ll', 'vgg16', 1)
# ('pgd', 'untargeted', 'vgg13', 4)
# ('pgd', 'untargeted', 'vgg16', 2)
# ('pgd', 'targeted_ll', 'vgg16', 0)
# ('pgd', 'untargeted', 'vgg16', 1)
# ('pgd', 'targeted_ll', 'vgg16', 2)
# ('pgd', 'untargeted', 'vgg11', 4)
# ('pgd', 'targeted_ll', 'vgg11', 1)
# ('pgd', 'targeted_ll', 'vgg19', 2)
# ('pgd', 'targeted_ll', 'vgg13', 4)
# ('pgd', 'untargeted', 'vgg19', 4)
# ('pgd', 'targeted_ll', 'vgg13', 1)
# ('pgd', 'targeted_ll', 'vgg13', 2)
# ('pgd', 'targeted_ll', 'vgg19', 4)
# ('pgd', 'untargeted', 'vgg11', 2)
# ('pgd', 'targeted_ll', 'vgg11', 2)
# ('pgd', 'targeted_ll', 'vgg16', 4)
# ('pgd', 'untargeted', 'vgg13', 0)
# ('pgd', 'targeted_ll', 'vgg11', 4)
# ('pgd', 'untargeted', 'vgg13', 2)
# ('pgd', 'untargeted', 'vgg11', 1)
# ('pgd', 'untargeted', 'vgg19', 1)
# ('pgd', 'targeted_ll', 'vgg13', 0)
# ('pgd', 'untargeted', 'vgg16', 4)
# ('pgd', 'untargeted', 'vgg19', 0)
# ('pgd', 'targeted_ll', 'vgg11', 0)
# ('original', 'original', 'original', '0')
# ('ResNet56v2', 'B', 'None', '3')
# ('cwl2', 'untargeted', 'ResNet56v1', 1)
# ('pgd', 'targeted_ll', 'ResNet20v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '2')
# ('pgd', 'targeted_ll', 'ResNet20v2', '2')
# ('pgd', 'untargeted', 'ResNet20v2', '3')
# ('pgd', 'targeted_ll', 'ResNet20v1', '0')
# ('pgd', 'untargeted', 'ResNet56v2', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '1')
# ('pgd', 'targeted_ll', 'ResNet20v1', '6')
# ('pgd', 'untargeted', 'ResNet20v1', '5')
# ('pgd', 'untargeted', 'ResNet56v2', '3')
# ('pgd', 'untargeted', 'ResNet20v2', '2')
# ('pgd', 'targeted_ll', 'ResNet56v1', '3')
# ('pgd', 'targeted_ll', 'ResNet56v2', '3')
# ('pgd', 'targeted_ll', 'ResNet20v2', '3')
# ('pgd', 'untargeted', 'ResNet20v2', '1')
# ('pgd', 'targeted_ll', 'ResNet56v1', '1')
# ('pgd', 'untargeted', 'ResNet56v1', '3')
# ('pgd', 'untargeted', 'ResNet20v1', '7')
# ('pgd', 'targeted_2nd', 'ResNet56v1', '7')
# ('pgd', 'untargeted', 'ResNet20v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v1', '2')
# ('pgd', 'untargeted', 'ResNet56v1', '2')
# ('pgd', 'targeted_ll', 'ResNet20v2', '1')
# ('pgd', 'targeted_ll', 'ResNet20v2', '0')
# ('pgd', 'untargeted', 'ResNet56v1', '1')
# ('pgd', 'targeted_ll', 'ResNet56v2', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '5')
# ('pgd', 'targeted_ll', 'ResNet56v1', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '2')
# ('pgd', 'untargeted', 'ResNet20v2', '0')
# ('pgd', 'untargeted', 'ResNet20v1', '6')
# ('pgd', 'targeted_ll', 'ResNet20v1', '4')
# ('cwl2', 'targeted_2nd', 'ResNet56v1', 0)
# ('cwl2', 'targeted_ll', 'ResNet56v1', 0)
# ('pgd', 'untargeted', 'ResNet20v1', '4')
# ('pgd', 'untargeted', 'ResNet56v2', '0')
# ('pgd', 'targeted_ll', 'ResNet20v1', '3')
# ('pgd', 'targeted_ll', 'ResNet20v1', '7')
# ('cwl2', 'targeted_ll', 'ResNet56v1', 1)
# ('pgd', 'untargeted', 'ResNet20v1', '0')
# ('pgd', 'untargeted', 'ResNet56v1', '0')
# ('pgd', 'untargeted', 'ResNet20v1', '3')
# ('pgd', 'untargeted', 'ResNet20v1', '2')
# ('cwl2', 'untargeted', 'ResNet56v1', 0)
# ('pgd', 'untargeted', 'ResNet56v2', '2')
# ('pgd', 'targeted_ll', 'vgg19', 1)
# ('pgd', 'untargeted', 'vgg13', 1)
# ('pgd', 'targeted_ll', 'vgg19', 0)
# ('pgd', 'untargeted', 'vgg11', 0)
# ('pgd', 'untargeted', 'vgg19', 2)
# ('pgd', 'untargeted', 'vgg16', 0)
# ('pgd', 'targeted_ll', 'vgg16', 1)
# ('pgd', 'untargeted', 'vgg13', 4)
# ('pgd', 'untargeted', 'vgg16', 2)
# ('pgd', 'targeted_ll', 'vgg16', 0)
# ('pgd', 'untargeted', 'vgg16', 1)
# ('pgd', 'targeted_ll', 'vgg16', 2)
# ('pgd', 'untargeted', 'vgg11', 4)
# ('pgd', 'targeted_ll', 'vgg11', 1)
# ('pgd', 'targeted_ll', 'vgg19', 2)
# ('pgd', 'targeted_ll', 'vgg13', 4)
# ('pgd', 'untargeted', 'vgg19', 4)
# ('pgd', 'targeted_ll', 'vgg13', 1)
# ('pgd', 'targeted_ll', 'vgg13', 2)
# ('pgd', 'targeted_ll', 'vgg19', 4)
# ('pgd', 'untargeted', 'vgg11', 2)
# ('pgd', 'targeted_ll', 'vgg11', 2)
# ('pgd', 'targeted_ll', 'vgg16', 4)
# ('pgd', 'untargeted', 'vgg13', 0)
# ('pgd', 'targeted_ll', 'vgg11', 4)
# ('pgd', 'untargeted', 'vgg13', 2)
# ('pgd', 'untargeted', 'vgg11', 1)
# ('pgd', 'untargeted', 'vgg19', 1)
# ('pgd', 'targeted_ll', 'vgg13', 0)
# ('pgd', 'untargeted', 'vgg16', 4)
# ('pgd', 'untargeted', 'vgg19', 0)
# ('pgd', 'targeted_ll', 'vgg11', 0)
# ('original', 'original', 'original', '0')

# %%
df3 = make_df(results)

# %%
df3.to_csv('results/master_results3.csv')

# %%
len(loaded_models)*len(loaded_testing_dataset)
# Out:
# 11376

# %%
## Make a result dataframe.
## It takes a lot of time.

folder = 'adversarial_models/full_and_fine/'
pattern = os.path.join(folder, '*.keras')
file_list = sorted(glob.glob(pattern))
loaded_models= {os.path.basename(f): load_model(f) for f in file_list}

results = {}  # structure: {(structure, attack type): [acc_0, acc_1, acc_2, acc_3]}

for filename, model in loaded_models.items():
    ###################
    if filename.startswith('ResNet20v1_ff_targeted'):
        print(filename)
    ###############

        # Example filename: 'ResNet20v1_ff_untargeted-adv_0.keras'
        # Extract family and index
        base = filename.replace('.keras','')
        parts = base.split('_')
        structure = parts[0]  # ResNet20v1, etc.
        attack_and_model_type = parts[2] + '_ff' 
        idx = int(parts[-1].split('-')[-1])  # last digit after -adv_
        testing_sample = x_test
        results = make_row(structure, attack_and_model_type, model,
                           idx = idx,results = results,
                           x = testing_sample,
                           y = y_test_categorical_20) # ff -> 20 dimensional answer
        for k, testing_sample in loaded_testing_dataset.items():
            name_of_testing_sample = 'adv_'+'_'.join(k[:-1])+'_'+str(k[-1]) # 'adv_pgd_targeted_ll_vgg11_0'
            results = make_row(structure, attack_and_model_type, model,
                               idx = idx,results = results,
                               x = testing_sample,
                               name_of_testing_sample = name_of_testing_sample,
                               y = y_test_categorical_20,
                               verbose = 0)
# Out:
# ResNet20v1_ff_targeted-adv_0.keras
# 313/313 [==============================] - 16s 2ms/step - loss: 0.8025 - acc: 0.8452
# ResNet20v1_ff_targeted-adv_1.keras
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8304 - acc: 0.8357
# ResNet20v1_ff_targeted-adv_2.keras
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6017 - acc: 0.8722
# ResNet20v1_ff_targeted-adv_3.keras
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5952 - acc: 0.8691

# %%
results
# Out:
# {('ResNet20v1', 'targeted-adv_ff'): {'acc_0_on_Original': 0.8452000021934509,
#   'loss_0_on_Original': 0.8024741411209106,
#   'acc_0_on_adv_cwl2_untargeted_ResNet56v1_1': 0.2492000013589859,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_1': 0.32170000672340393,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet56v2_2': 0.2833999991416931,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet20v2_2': 0.6628999710083008,
#   'acc_0_on_adv_pgd_untargeted_ResNet20v2_3': 0.796500027179718,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_0': 0.4025999903678894,
#   'acc_0_on_adv_pgd_untargeted_ResNet56v2_1': 0.8295999765396118,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet56v2_1': 0.7512000203132629,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_6': 0.46140000224113464,
#   'acc_0_on_adv_pgd_untargeted_ResNet20v1_5': 0.8374999761581421,
#   'acc_0_on_adv_pgd_untargeted_ResNet56v2_3': 0.15530000627040863,
#   'acc_0_on_adv_pgd_untargeted_ResNet20v2_2': 0.7870000004768372,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet56v1_3': 0.16949999332427979,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet56v2_3': 0.011300000362098217,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet20v2_3': 0.6771000027656555,
#   'acc_0_on_adv_pgd_untargeted_ResNet20v2_1': 0.724399983882904,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet56v1_1': 0.08240000158548355,
#   'acc_0_on_adv_pgd_untargeted_ResNet56v1_3': 0.6151999831199646,
#   'acc_0_on_adv_pgd_untargeted_ResNet20v1_7': 0.1371999979019165,
#   'acc_0_on_adv_pgd_targeted_2nd_ResNet56v1_7': 0.006300000008195639,
#   'acc_0_on_adv_pgd_untargeted_ResNet20v1_1': 0.6808000206947327,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet56v1_2': 0.701200008392334,
#   'acc_0_on_adv_pgd_untargeted_ResNet56v1_2': 0.8136000037193298,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet20v2_1': 0.5412999987602234,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet20v2_0': 0.7529000043869019,
#   'acc_0_on_adv_pgd_untargeted_ResNet56v1_1': 0.5116000175476074,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet56v2_0': 0.042100001126527786,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_5': 0.7494000196456909,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet56v1_0': 0.01769999973475933,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_2': 0.7815999984741211,
#   'acc_0_on_adv_pgd_untargeted_ResNet20v2_0': 0.8230999708175659,
#   'acc_0_on_adv_pgd_untargeted_ResNet20v1_6': 0.7156000137329102,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_4': 0.07329999655485153,
#   'acc_0_on_adv_cwl2_targeted_2nd_ResNet56v1_0': 0.8212000131607056,
#   'acc_0_on_adv_cwl2_targeted_ll_ResNet56v1_0': 0.8324000239372253,
#   'acc_0_on_adv_pgd_untargeted_ResNet20v1_4': 0.23350000381469727,
#   'acc_0_on_adv_pgd_untargeted_ResNet56v2_0': 0.1899999976158142,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_3': 0.6362000107765198,
#   'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_7': 0.00839999970048666,
#   'acc_0_on_adv_cwl2_targeted_ll_ResNet56v1_1': 0.8389000296592712,
#   'acc_0_on_adv_pgd_untargeted_ResNet20v1_0': 0.7429999709129333,
#   'acc_0_on_adv_pgd_untargeted_ResNet56v1_0': 0.007300000172108412,
#   'acc_0_on_adv_pgd_untargeted_ResNet20v1_3': 0.8105000257492065,
#   'acc_0_on_adv_pgd_untargeted_ResNet20v1_2': 0.8417999744415283,
#   'acc_0_on_adv_cwl2_untargeted_ResNet56v1_0': 0.8224999904632568,
#   'acc_0_on_adv_pgd_untargeted_ResNet56v2_2': 0.5526000261306763,
#   'acc_0_on_adv_pgd_targeted_ll_vgg19_1': 0.7372000217437744,
#   'acc_0_on_adv_pgd_untargeted_vgg13_1': 0.8472999930381775,
#   'acc_0_on_adv_pgd_targeted_ll_vgg19_0': 0.7354999780654907,
#   'acc_0_on_adv_pgd_untargeted_vgg11_0': 0.8130999803543091,
#   'acc_0_on_adv_pgd_untargeted_vgg19_2': 0.8366000056266785,
#   'acc_0_on_adv_pgd_untargeted_vgg16_0': 0.8431000113487244,
#   'acc_0_on_adv_pgd_targeted_ll_vgg16_1': 0.7275999784469604,
#   'acc_0_on_adv_pgd_untargeted_vgg13_4': 0.8449000120162964,
#   'acc_0_on_adv_pgd_untargeted_vgg16_2': 0.8371999859809875,
#   'acc_0_on_adv_pgd_targeted_ll_vgg16_0': 0.7573999762535095,
#   'acc_0_on_adv_pgd_untargeted_vgg16_1': 0.8331000208854675,
#   'acc_0_on_adv_pgd_targeted_ll_vgg16_2': 0.741599977016449,
#   'acc_0_on_adv_pgd_untargeted_vgg11_4': 0.8198000192642212,
#   'acc_0_on_adv_pgd_targeted_ll_vgg11_1': 0.729200005531311,
#   'acc_0_on_adv_pgd_targeted_ll_vgg19_2': 0.7421000003814697,
#   'acc_0_on_adv_pgd_targeted_ll_vgg13_4': 0.7436000108718872,
#   'acc_0_on_adv_pgd_untargeted_vgg19_4': 0.847100019454956,
#   'acc_0_on_adv_pgd_targeted_ll_vgg13_1': 0.7455000281333923,
#   'acc_0_on_adv_pgd_targeted_ll_vgg13_2': 0.7258999943733215,
#   'acc_0_on_adv_pgd_targeted_ll_vgg19_4': 0.7508000135421753,
#   'acc_0_on_adv_pgd_untargeted_vgg11_2': 0.8177000284194946,
#   'acc_0_on_adv_pgd_targeted_ll_vgg11_2': 0.7495999932289124,
#   'acc_0_on_adv_pgd_targeted_ll_vgg16_4': 0.7455999851226807,
#   'acc_0_on_adv_pgd_untargeted_vgg13_0': 0.8428000211715698,
#   'acc_0_on_adv_pgd_targeted_ll_vgg11_4': 0.7458999752998352,
#   'acc_0_on_adv_pgd_untargeted_vgg13_2': 0.84170001745224,
#   'acc_0_on_adv_pgd_untargeted_vgg11_1': 0.8148999810218811,
#   'acc_0_on_adv_pgd_untargeted_vgg19_1': 0.8363999724388123,
#   'acc_0_on_adv_pgd_targeted_ll_vgg13_0': 0.7595999836921692,
#   'acc_0_on_adv_pgd_untargeted_vgg16_4': 0.8420000076293945,
#   'acc_0_on_adv_pgd_untargeted_vgg19_0': 0.8457000255584717,
#   'acc_0_on_adv_pgd_targeted_ll_vgg11_0': 0.7623999714851379,
#   'acc_1_on_Original': 0.8356999754905701,
#   'loss_1_on_Original': 0.8304398655891418,
#   'acc_1_on_adv_cwl2_untargeted_ResNet56v1_1': 0.24459999799728394,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_1': 0.5094000101089478,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet56v2_2': 0.26089999079704285,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet20v2_2': 0.6754999756813049,
#   'acc_1_on_adv_pgd_untargeted_ResNet20v2_3': 0.7828999757766724,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_0': 0.6862000226974487,
#   'acc_1_on_adv_pgd_untargeted_ResNet56v2_1': 0.8065999746322632,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet56v2_1': 0.7170000076293945,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_6': 0.42559999227523804,
#   'acc_1_on_adv_pgd_untargeted_ResNet20v1_5': 0.8122000098228455,
#   'acc_1_on_adv_pgd_untargeted_ResNet56v2_3': 0.218299999833107,
#   'acc_1_on_adv_pgd_untargeted_ResNet20v2_2': 0.7770000100135803,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet56v1_3': 0.4291999936103821,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet56v2_3': 0.032099999487400055,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet20v2_3': 0.6753000020980835,
#   'acc_1_on_adv_pgd_untargeted_ResNet20v2_1': 0.6880000233650208,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet56v1_1': 0.6455000042915344,
#   'acc_1_on_adv_pgd_untargeted_ResNet56v1_3': 0.5382000207901001,
#   'acc_1_on_adv_pgd_untargeted_ResNet20v1_7': 0.310699999332428,
#   'acc_1_on_adv_pgd_targeted_2nd_ResNet56v1_7': 0.007600000128149986,
#   'acc_1_on_adv_pgd_untargeted_ResNet20v1_1': 0.6891999840736389,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet56v1_2': 0.6815000176429749,
#   'acc_1_on_adv_pgd_untargeted_ResNet56v1_2': 0.7879999876022339,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet20v2_1': 0.5800999999046326,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet20v2_0': 0.7178999781608582,
#   'acc_1_on_adv_pgd_untargeted_ResNet56v1_1': 0.7738999724388123,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet56v2_0': 0.002099999925121665,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_5': 0.7192000150680542,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet56v1_0': 0.01860000006854534,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_2': 0.7486000061035156,
#   'acc_1_on_adv_pgd_untargeted_ResNet20v2_0': 0.7978000044822693,
#   'acc_1_on_adv_pgd_untargeted_ResNet20v1_6': 0.6168000102043152,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_4': 0.010999999940395355,
#   'acc_1_on_adv_cwl2_targeted_2nd_ResNet56v1_0': 0.8014000058174133,
#   'acc_1_on_adv_cwl2_targeted_ll_ResNet56v1_0': 0.8271999955177307,
#   'acc_1_on_adv_pgd_untargeted_ResNet20v1_4': 0.1080000028014183,
#   'acc_1_on_adv_pgd_untargeted_ResNet56v2_0': 0.022700000554323196,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_3': 0.5649999976158142,
#   'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_7': 0.17800000309944153,
#   'acc_1_on_adv_cwl2_targeted_ll_ResNet56v1_1': 0.8305000066757202,
#   'acc_1_on_adv_pgd_untargeted_ResNet20v1_0': 0.7878000140190125,
#   'acc_1_on_adv_pgd_untargeted_ResNet56v1_0': 0.008500000461935997,
#   'acc_1_on_adv_pgd_untargeted_ResNet20v1_3': 0.7802000045776367,
#   'acc_1_on_adv_pgd_untargeted_ResNet20v1_2': 0.8198000192642212,
#   'acc_1_on_adv_cwl2_untargeted_ResNet56v1_0': 0.8050000071525574,
#   'acc_1_on_adv_pgd_untargeted_ResNet56v2_2': 0.4765999913215637,
#   'acc_1_on_adv_pgd_targeted_ll_vgg19_1': 0.7157999873161316,
#   'acc_1_on_adv_pgd_untargeted_vgg13_1': 0.8334000110626221,
#   'acc_1_on_adv_pgd_targeted_ll_vgg19_0': 0.7098000049591064,
#   'acc_1_on_adv_pgd_untargeted_vgg11_0': 0.8034999966621399,
#   'acc_1_on_adv_pgd_untargeted_vgg19_2': 0.8251000046730042,
#   'acc_1_on_adv_pgd_untargeted_vgg16_0': 0.8263999819755554,
#   'acc_1_on_adv_pgd_targeted_ll_vgg16_1': 0.7120000123977661,
#   'acc_1_on_adv_pgd_untargeted_vgg13_4': 0.8345000147819519,
#   'acc_1_on_adv_pgd_untargeted_vgg16_2': 0.8263000249862671,
#   'acc_1_on_adv_pgd_targeted_ll_vgg16_0': 0.7289999723434448,
#   'acc_1_on_adv_pgd_untargeted_vgg16_1': 0.8228999972343445,
#   'acc_1_on_adv_pgd_targeted_ll_vgg16_2': 0.7149999737739563,
#   'acc_1_on_adv_pgd_untargeted_vgg11_4': 0.8030999898910522,
#   'acc_1_on_adv_pgd_targeted_ll_vgg11_1': 0.7049000263214111,
#   'acc_1_on_adv_pgd_targeted_ll_vgg19_2': 0.7099999785423279,
#   'acc_1_on_adv_pgd_targeted_ll_vgg13_4': 0.7208999991416931,
#   'acc_1_on_adv_pgd_untargeted_vgg19_4': 0.8314999938011169,
#   'acc_1_on_adv_pgd_targeted_ll_vgg13_1': 0.7203999757766724,
#   'acc_1_on_adv_pgd_targeted_ll_vgg13_2': 0.7063999772071838,
#   'acc_1_on_adv_pgd_targeted_ll_vgg19_4': 0.7303000092506409,
#   'acc_1_on_adv_pgd_untargeted_vgg11_2': 0.802299976348877,
#   'acc_1_on_adv_pgd_targeted_ll_vgg11_2': 0.7218000292778015,
#   'acc_1_on_adv_pgd_targeted_ll_vgg16_4': 0.7258999943733215,
#   'acc_1_on_adv_pgd_untargeted_vgg13_0': 0.8302000164985657,
#   'acc_1_on_adv_pgd_targeted_ll_vgg11_4': 0.718999981880188,
#   'acc_1_on_adv_pgd_untargeted_vgg13_2': 0.8348000049591064,
#   'acc_1_on_adv_pgd_untargeted_vgg11_1': 0.8004999756813049,
#   'acc_1_on_adv_pgd_untargeted_vgg19_1': 0.822700023651123,
#   'acc_1_on_adv_pgd_targeted_ll_vgg13_0': 0.7371000051498413,
#   'acc_1_on_adv_pgd_untargeted_vgg16_4': 0.8270000219345093,
#   'acc_1_on_adv_pgd_untargeted_vgg19_0': 0.8374000191688538,
#   'acc_1_on_adv_pgd_targeted_ll_vgg11_0': 0.7293000221252441,
#   'acc_2_on_Original': 0.8722000122070312,
#   'loss_2_on_Original': 0.6017375588417053,
#   'acc_2_on_adv_cwl2_untargeted_ResNet56v1_1': 0.2533000111579895,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet20v1_1': 0.24459999799728394,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet56v2_2': 0.2232999950647354,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet20v2_2': 0.7882000207901001,
#   'acc_2_on_adv_pgd_untargeted_ResNet20v2_3': 0.8432999849319458,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet20v1_0': 0.6025999784469604,
#   'acc_2_on_adv_pgd_untargeted_ResNet56v2_1': 0.8597999811172485,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet56v2_1': 0.7986999750137329,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet20v1_6': 0.545799970626831,
#   'acc_2_on_adv_pgd_untargeted_ResNet20v1_5': 0.8389000296592712,
#   'acc_2_on_adv_pgd_untargeted_ResNet56v2_3': 0.13920000195503235,
#   'acc_2_on_adv_pgd_untargeted_ResNet20v2_2': 0.8360999822616577,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet56v1_3': 0.06800000369548798,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet56v2_3': 0.014800000004470348,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet20v2_3': 0.7763000130653381,
#   'acc_2_on_adv_pgd_untargeted_ResNet20v2_1': 0.7519999742507935,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet56v1_1': 0.5881999731063843,
#   'acc_2_on_adv_pgd_untargeted_ResNet56v1_3': 0.36570000648498535,
#   'acc_2_on_adv_pgd_untargeted_ResNet20v1_7': 0.16369999945163727,
#   'acc_2_on_adv_pgd_targeted_2nd_ResNet56v1_7': 0.00839999970048666,
#   'acc_2_on_adv_pgd_untargeted_ResNet20v1_1': 0.5820000171661377,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet56v1_2': 0.8029999732971191,
#   'acc_2_on_adv_pgd_untargeted_ResNet56v1_2': 0.853600025177002,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet20v2_1': 0.6690000295639038,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet20v2_0': 0.8048999905586243,
#   'acc_2_on_adv_pgd_untargeted_ResNet56v1_1': 0.7666000127792358,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet56v2_0': 0.0034000000450760126,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet20v1_5': 0.7718999981880188,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet56v1_0': 0.017799999564886093,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet20v1_2': 0.8198999762535095,
#   'acc_2_on_adv_pgd_untargeted_ResNet20v2_0': 0.8546000123023987,
#   'acc_2_on_adv_pgd_untargeted_ResNet20v1_6': 0.6744999885559082,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet20v1_4': 0.015300000086426735,
#   'acc_2_on_adv_cwl2_targeted_2nd_ResNet56v1_0': 0.8449000120162964,
#   'acc_2_on_adv_cwl2_targeted_ll_ResNet56v1_0': 0.8626999855041504,
#   'acc_2_on_adv_pgd_untargeted_ResNet20v1_4': 0.11219999939203262,
#   'acc_2_on_adv_pgd_untargeted_ResNet56v2_0': 0.04569999873638153,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet20v1_3': 0.7426000237464905,
#   'acc_2_on_adv_pgd_targeted_ll_ResNet20v1_7': 0.01730000041425228,
#   'acc_2_on_adv_cwl2_targeted_ll_ResNet56v1_1': 0.8691999912261963,
#   'acc_2_on_adv_pgd_untargeted_ResNet20v1_0': 0.7858999967575073,
#   'acc_2_on_adv_pgd_untargeted_ResNet56v1_0': 0.008899999782443047,
#   'acc_2_on_adv_pgd_untargeted_ResNet20v1_3': 0.8493000268936157,
#   'acc_2_on_adv_pgd_untargeted_ResNet20v1_2': 0.8648999929428101,
#   'acc_2_on_adv_cwl2_untargeted_ResNet56v1_0': 0.8464999794960022,
#   'acc_2_on_adv_pgd_untargeted_ResNet56v2_2': 0.44609999656677246,
#   'acc_2_on_adv_pgd_targeted_ll_vgg19_1': 0.7786999940872192,
#   'acc_2_on_adv_pgd_untargeted_vgg13_1': 0.8639000058174133,
#   'acc_2_on_adv_pgd_targeted_ll_vgg19_0': 0.7749000191688538,
#   'acc_2_on_adv_pgd_untargeted_vgg11_0': 0.8392000198364258,
#   'acc_2_on_adv_pgd_untargeted_vgg19_2': 0.8557999730110168,
#   'acc_2_on_adv_pgd_untargeted_vgg16_0': 0.8590999841690063,
#   'acc_2_on_adv_pgd_targeted_ll_vgg16_1': 0.7720999717712402,
#   'acc_2_on_adv_pgd_untargeted_vgg13_4': 0.8623999953269958,
#   'acc_2_on_adv_pgd_untargeted_vgg16_2': 0.8565999865531921,
#   'acc_2_on_adv_pgd_targeted_ll_vgg16_0': 0.7825999855995178,
#   'acc_2_on_adv_pgd_untargeted_vgg16_1': 0.8514999747276306,
#   'acc_2_on_adv_pgd_targeted_ll_vgg16_2': 0.7760999798774719,
#   'acc_2_on_adv_pgd_untargeted_vgg11_4': 0.8396000266075134,
#   'acc_2_on_adv_pgd_targeted_ll_vgg11_1': 0.7724999785423279,
#   'acc_2_on_adv_pgd_targeted_ll_vgg19_2': 0.779699981212616,
#   'acc_2_on_adv_pgd_targeted_ll_vgg13_4': 0.7771000266075134,
#   'acc_2_on_adv_pgd_untargeted_vgg19_4': 0.8644999861717224,
#   'acc_2_on_adv_pgd_targeted_ll_vgg13_1': 0.7803000211715698,
#   'acc_2_on_adv_pgd_targeted_ll_vgg13_2': 0.7706999778747559,
#   'acc_2_on_adv_pgd_targeted_ll_vgg19_4': 0.788100004196167,
#   'acc_2_on_adv_pgd_untargeted_vgg11_2': 0.839900016784668,
#   'acc_2_on_adv_pgd_targeted_ll_vgg11_2': 0.7889000177383423,
#   'acc_2_on_adv_pgd_targeted_ll_vgg16_4': 0.7868000268936157,
#   'acc_2_on_adv_pgd_untargeted_vgg13_0': 0.8603000044822693,
#   'acc_2_on_adv_pgd_targeted_ll_vgg11_4': 0.7786999940872192,
#   'acc_2_on_adv_pgd_untargeted_vgg13_2': 0.8597999811172485,
#   'acc_2_on_adv_pgd_untargeted_vgg11_1': 0.8361999988555908,
#   'acc_2_on_adv_pgd_untargeted_vgg19_1': 0.8515999913215637,
#   'acc_2_on_adv_pgd_targeted_ll_vgg13_0': 0.7892000079154968,
#   'acc_2_on_adv_pgd_untargeted_vgg16_4': 0.8560000061988831,
#   'acc_2_on_adv_pgd_untargeted_vgg19_0': 0.8658999800682068,
#   'acc_2_on_adv_pgd_targeted_ll_vgg11_0': 0.7949000000953674,
#   'acc_3_on_Original': 0.8690999746322632,
#   'loss_3_on_Original': 0.5952209234237671,
#   'acc_3_on_adv_cwl2_untargeted_ResNet56v1_1': 0.2540999948978424,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet20v1_1': 0.5437999963760376,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet56v2_2': 0.04360000044107437,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet20v2_2': 0.5763000249862671,
#   'acc_3_on_adv_pgd_untargeted_ResNet20v2_3': 0.8246999979019165,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet20v1_0': 0.6895999908447266,
#   'acc_3_on_adv_pgd_untargeted_ResNet56v2_1': 0.853600025177002,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet56v2_1': 0.7929999828338623,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet20v1_6': 0.18379999697208405,
#   'acc_3_on_adv_pgd_untargeted_ResNet20v1_5': 0.8615000247955322,
#   'acc_3_on_adv_pgd_untargeted_ResNet56v2_3': 0.2013999968767166,
#   'acc_3_on_adv_pgd_untargeted_ResNet20v2_2': 0.7530999779701233,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet56v1_3': 0.5638999938964844,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet56v2_3': 0.015799999237060547,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet20v2_3': 0.7283999919891357,
#   'acc_3_on_adv_pgd_untargeted_ResNet20v2_1': 0.7419000267982483,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet56v1_1': 0.16369999945163727,
#   'acc_3_on_adv_pgd_untargeted_ResNet56v1_3': 0.7839999794960022,
#   'acc_3_on_adv_pgd_untargeted_ResNet20v1_7': 0.19449999928474426,
#   'acc_3_on_adv_pgd_targeted_2nd_ResNet56v1_7': 0.006200000178068876,
#   'acc_3_on_adv_pgd_untargeted_ResNet20v1_1': 0.7753999829292297,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet56v1_2': 0.7024000287055969,
#   'acc_3_on_adv_pgd_untargeted_ResNet56v1_2': 0.8414999842643738,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet20v2_1': 0.54830002784729,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet20v2_0': 0.7857000231742859,
#   'acc_3_on_adv_pgd_untargeted_ResNet56v1_1': 0.6689000129699707,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet56v2_0': 0.0017000000225380063,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet20v1_5': 0.7903000116348267,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet56v1_0': 0.017899999395012856,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet20v1_2': 0.8065000176429749,
#   'acc_3_on_adv_pgd_untargeted_ResNet20v2_0': 0.8503999710083008,
#   'acc_3_on_adv_pgd_untargeted_ResNet20v1_6': 0.5823000073432922,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet20v1_4': 0.004800000227987766,
#   'acc_3_on_adv_cwl2_targeted_2nd_ResNet56v1_0': 0.8431000113487244,
#   'acc_3_on_adv_cwl2_targeted_ll_ResNet56v1_0': 0.8565999865531921,
#   'acc_3_on_adv_pgd_untargeted_ResNet20v1_4': 0.07050000131130219,
#   'acc_3_on_adv_pgd_untargeted_ResNet56v2_0': 0.019600000232458115,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet20v1_3': 0.6812999844551086,
#   'acc_3_on_adv_pgd_targeted_ll_ResNet20v1_7': 0.014399999752640724,
#   'acc_3_on_adv_cwl2_targeted_ll_ResNet56v1_1': 0.8621000051498413,
#   'acc_3_on_adv_pgd_untargeted_ResNet20v1_0': 0.8276000022888184,
#   'acc_3_on_adv_pgd_untargeted_ResNet56v1_0': 0.0071000000461936,
#   'acc_3_on_adv_pgd_untargeted_ResNet20v1_3': 0.8409000039100647,
#   'acc_3_on_adv_pgd_untargeted_ResNet20v1_2': 0.8615000247955322,
#   'acc_3_on_adv_cwl2_untargeted_ResNet56v1_0': 0.8446000218391418,
#   'acc_3_on_adv_pgd_untargeted_ResNet56v2_2': 0.2937000095844269,
#   'acc_3_on_adv_pgd_targeted_ll_vgg19_1': 0.7641000151634216,
#   'acc_3_on_adv_pgd_untargeted_vgg13_1': 0.8598999977111816,
#   'acc_3_on_adv_pgd_targeted_ll_vgg19_0': 0.7660999894142151,
#   'acc_3_on_adv_pgd_untargeted_vgg11_0': 0.8359000086784363,
#   'acc_3_on_adv_pgd_untargeted_vgg19_2': 0.850600004196167,
#   'acc_3_on_adv_pgd_untargeted_vgg16_0': 0.8561999797821045,
#   'acc_3_on_adv_pgd_targeted_ll_vgg16_1': 0.7638000249862671,
#   'acc_3_on_adv_pgd_untargeted_vgg13_4': 0.8555999994277954,
#   'acc_3_on_adv_pgd_untargeted_vgg16_2': 0.8496999740600586,
#   'acc_3_on_adv_pgd_targeted_ll_vgg16_0': 0.7774999737739563,
#   'acc_3_on_adv_pgd_untargeted_vgg16_1': 0.8456000089645386,
#   'acc_3_on_adv_pgd_targeted_ll_vgg16_2': 0.7651000022888184,
#   'acc_3_on_adv_pgd_untargeted_vgg11_4': 0.8330000042915344,
#   'acc_3_on_adv_pgd_targeted_ll_vgg11_1': 0.7666000127792358,
#   'acc_3_on_adv_pgd_targeted_ll_vgg19_2': 0.765500009059906,
#   'acc_3_on_adv_pgd_targeted_ll_vgg13_4': 0.7698000073432922,
#   'acc_3_on_adv_pgd_untargeted_vgg19_4': 0.8592000007629395,
#   'acc_3_on_adv_pgd_targeted_ll_vgg13_1': 0.7759000062942505,
#   'acc_3_on_adv_pgd_targeted_ll_vgg13_2': 0.7623999714851379,
#   'acc_3_on_adv_pgd_targeted_ll_vgg19_4': 0.779699981212616,
#   'acc_3_on_adv_pgd_untargeted_vgg11_2': 0.8320000171661377,
#   'acc_3_on_adv_pgd_targeted_ll_vgg11_2': 0.7807999849319458,
#   'acc_3_on_adv_pgd_targeted_ll_vgg16_4': 0.7745000123977661,
#   'acc_3_on_adv_pgd_untargeted_vgg13_0': 0.8568000197410583,
#   'acc_3_on_adv_pgd_targeted_ll_vgg11_4': 0.7750999927520752,
#   'acc_3_on_adv_pgd_untargeted_vgg13_2': 0.8540999889373779,
#   'acc_3_on_adv_pgd_untargeted_vgg11_1': 0.8306999802589417,
#   'acc_3_on_adv_pgd_untargeted_vgg19_1': 0.849399983882904,
#   'acc_3_on_adv_pgd_targeted_ll_vgg13_0': 0.786300003528595,
#   'acc_3_on_adv_pgd_untargeted_vgg16_4': 0.8515999913215637,
#   'acc_3_on_adv_pgd_untargeted_vgg19_0': 0.8619999885559082,
#   'acc_3_on_adv_pgd_targeted_ll_vgg11_0': 0.786300003528595}}

# %%
results
for (structure, attack_type), eval_dict in results.items():
    accs = [eval_dict.get(f'acc_{i}', np.nan) for i in range(len(eval_dict))]
    accs.sort(reverse = True)
    acc_av = np.nanmean(accs)
    losses = [eval_dict.get(f'loss_{i}', np.nan) for i in range(len(eval_dict))]
    losses.sort()
    losses_av = np.nanmean(losses)
    row = [f'{structure}']+[f'{attack_type}'] + [acc_av] + [losses_av]
    rows.append(row)
# Out:
# /scratch/9181562.1.l40s/ipykernel_2063032/4189311576.py:5: RuntimeWarning: Mean of empty slice
#   acc_av = np.nanmean(accs)
# /scratch/9181562.1.l40s/ipykernel_2063032/4189311576.py:8: RuntimeWarning: Mean of empty slice
#   losses_av = np.nanmean(losses)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/9181562.1.l40s/ipykernel_2063032/4189311576.py in <cell line: 2>()
#       8     losses_av = np.nanmean(losses)
#       9     row = [f'{structure}']+[f'{attack_type}'] + [acc_av] + [losses_av]
# ---> 10     rows.append(row)
#
# NameError: name 'rows' is not defined

# %%
# Out:
# {'acc_0_on_Original': 0.7099999785423279,
#  'loss_0_on_Original': 1.3412822484970093,
#  'acc_0_on_adv_cwl2_untargeted_ResNet56v2_1': 0.10100000351667404,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_1': 0.12290000170469284,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet56v2_2': 0.12700000405311584,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet20v2_2': 0.1688999980688095,
#  'acc_0_on_adv_pgd_untargeted_ResNet20v2_3': 0.258899986743927,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_0': 0.21459999680519104,
#  'acc_0_on_adv_pgd_untargeted_ResNet56v2_1': 0.22269999980926514,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet56v2_1': 0.131400004029274,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_6': 0.09629999846220016,
#  'acc_0_on_adv_pgd_untargeted_ResNet20v1_5': 0.2395000010728836,
#  'acc_0_on_adv_pgd_untargeted_ResNet56v2_3': 0.1534000039100647,
#  'acc_0_on_adv_pgd_untargeted_ResNet20v2_2': 0.2535000145435333,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet56v1_3': 0.0737999975681305,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet56v2_3': 0.0917000025510788,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet20v2_3': 0.17100000381469727,
#  'acc_0_on_adv_pgd_untargeted_ResNet20v2_1': 0.3382999897003174,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet56v1_1': 0.0851999968290329,
#  'acc_0_on_adv_pgd_untargeted_ResNet56v1_3': 0.1665000021457672,
#  'acc_0_on_adv_pgd_untargeted_ResNet20v1_7': 0.14710000157356262,
#  'acc_0_on_adv_pgd_targeted_2nd_ResNet56v1_7': 0.06279999762773514,
#  'acc_0_on_adv_pgd_untargeted_ResNet20v1_1': 0.2110999971628189,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet56v1_2': 0.13050000369548798,
#  'acc_0_on_adv_pgd_untargeted_ResNet56v1_2': 0.26510000228881836,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet20v2_1': 0.26989999413490295,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet20v2_0': 0.10649999976158142,
#  'acc_0_on_adv_pgd_untargeted_ResNet56v1_1': 0.17000000178813934,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet56v2_0': 0.07180000096559525,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_5': 0.11410000175237656,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet56v1_0': 0.09619999676942825,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_2': 0.15729999542236328,
#  'acc_0_on_adv_pgd_untargeted_ResNet20v2_0': 0.18709999322891235,
#  'acc_0_on_adv_pgd_untargeted_ResNet20v1_6': 0.1729000061750412,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_4': 0.08709999918937683,
#  'acc_0_on_adv_cwl2_targeted_2nd_ResNet20v1_0': 0.3174999952316284,
#  'acc_0_on_adv_cwl2_targeted_ll_ResNet20v1_0': 0.682699978351593,
#  'acc_0_on_adv_pgd_untargeted_ResNet20v1_4': 0.15109999477863312,
#  'acc_0_on_adv_pgd_untargeted_ResNet56v2_0': 0.11429999768733978,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_3': 0.09030000120401382,
#  'acc_0_on_adv_pgd_targeted_ll_ResNet20v1_7': 0.08699999749660492,
#  'acc_0_on_adv_cwl2_targeted_ll_ResNet20v1_1': 0.6891000270843506,
#  'acc_0_on_adv_pgd_untargeted_ResNet20v1_0': 0.30640000104904175,
#  'acc_0_on_adv_pgd_untargeted_ResNet56v1_0': 0.05649999901652336,
#  'acc_0_on_adv_pgd_untargeted_ResNet20v1_3': 0.18469999730587006,
#  'acc_0_on_adv_pgd_untargeted_ResNet20v1_2': 0.275299996137619,
#  'acc_0_on_adv_cwl2_untargeted_ResNet20v1_0': 0.3174999952316284,
#  'acc_0_on_adv_pgd_untargeted_ResNet56v2_2': 0.17790000140666962,
#  'acc_0_on_adv_pgd_targeted_ll_vgg19_1': 0.4198000133037567,
#  'acc_0_on_adv_pgd_untargeted_vgg13_1': 0.6930000185966492,
#  'acc_0_on_adv_pgd_targeted_ll_vgg19_0': 0.40630000829696655,
#  'acc_0_on_adv_pgd_untargeted_vgg11_0': 0.5733000040054321,
#  'acc_0_on_adv_pgd_untargeted_vgg19_2': 0.6531999707221985,
#  'acc_0_on_adv_pgd_untargeted_vgg16_0': 0.6611999869346619,
#  'acc_0_on_adv_pgd_targeted_ll_vgg16_1': 0.41350001096725464,
#  'acc_0_on_adv_pgd_untargeted_vgg13_4': 0.652999997138977,
#  'acc_0_on_adv_pgd_untargeted_vgg16_2': 0.607699990272522,
#  'acc_0_on_adv_pgd_targeted_ll_vgg16_0': 0.4251999855041504,
#  'acc_0_on_adv_pgd_untargeted_vgg16_1': 0.6262000203132629,
#  'acc_0_on_adv_pgd_targeted_ll_vgg16_2': 0.37529999017715454,
#  'acc_0_on_adv_pgd_untargeted_vgg11_4': 0.6001999974250793,
#  'acc_0_on_adv_pgd_targeted_ll_vgg11_1': 0.4207000136375427,
#  'acc_0_on_adv_pgd_targeted_ll_vgg19_2': 0.4178999960422516,
#  'acc_0_on_adv_pgd_targeted_ll_vgg13_4': 0.45019999146461487,
#  'acc_0_on_adv_pgd_untargeted_vgg19_4': 0.6858000159263611,
#  'acc_0_on_adv_pgd_targeted_ll_vgg13_1': 0.4733999967575073,
#  'acc_0_on_adv_pgd_targeted_ll_vgg13_2': 0.44940000772476196,
#  'acc_0_on_adv_pgd_targeted_ll_vgg19_4': 0.44440001249313354,
#  'acc_0_on_adv_pgd_untargeted_vgg11_2': 0.5946999788284302,
#  'acc_0_on_adv_pgd_targeted_ll_vgg11_2': 0.39469999074935913,
#  'acc_0_on_adv_pgd_targeted_ll_vgg16_4': 0.41449999809265137,
#  'acc_0_on_adv_pgd_untargeted_vgg13_0': 0.6485000252723694,
#  'acc_0_on_adv_pgd_targeted_ll_vgg11_4': 0.3961000144481659,
#  'acc_0_on_adv_pgd_untargeted_vgg13_2': 0.6717000007629395,
#  'acc_0_on_adv_pgd_untargeted_vgg11_1': 0.6154000163078308,
#  'acc_0_on_adv_pgd_untargeted_vgg19_1': 0.6434000134468079,
#  'acc_0_on_adv_pgd_targeted_ll_vgg13_0': 0.43230000138282776,
#  'acc_0_on_adv_pgd_untargeted_vgg16_4': 0.6559000015258789,
#  'acc_0_on_adv_pgd_untargeted_vgg19_0': 0.649399995803833,
#  'acc_0_on_adv_pgd_targeted_ll_vgg11_0': 0.39640000462532043,
#  'acc_1_on_Original': 0.6449000239372253,
#  'loss_1_on_Original': 1.6508654356002808,
#  'acc_1_on_adv_cwl2_untargeted_ResNet56v2_1': 0.07329999655485153,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_1': 0.04740000143647194,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet56v2_2': 0.05920000001788139,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet20v2_2': 0.08560000360012054,
#  'acc_1_on_adv_pgd_untargeted_ResNet20v2_3': 0.24330000579357147,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_0': 0.06369999796152115,
#  'acc_1_on_adv_pgd_untargeted_ResNet56v2_1': 0.16619999706745148,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet56v2_1': 0.07580000162124634,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_6': 0.04639999940991402,
#  'acc_1_on_adv_pgd_untargeted_ResNet20v1_5': 0.18070000410079956,
#  'acc_1_on_adv_pgd_untargeted_ResNet56v2_3': 0.07639999687671661,
#  'acc_1_on_adv_pgd_untargeted_ResNet20v2_2': 0.16429999470710754,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet56v1_3': 0.029899999499320984,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet56v2_3': 0.027499999850988388,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet20v2_3': 0.1615000069141388,
#  'acc_1_on_adv_pgd_untargeted_ResNet20v2_1': 0.2037000060081482,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet56v1_1': 0.03139999881386757,
#  'acc_1_on_adv_pgd_untargeted_ResNet56v1_3': 0.1039000004529953,
#  'acc_1_on_adv_pgd_untargeted_ResNet20v1_7': 0.06679999828338623,
#  'acc_1_on_adv_pgd_targeted_2nd_ResNet56v1_7': 0.018699999898672104,
#  'acc_1_on_adv_pgd_untargeted_ResNet20v1_1': 0.13089999556541443,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet56v1_2': 0.058800000697374344,
#  'acc_1_on_adv_pgd_untargeted_ResNet56v1_2': 0.16380000114440918,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet20v2_1': 0.14579999446868896,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet20v2_0': 0.06390000134706497,
#  'acc_1_on_adv_pgd_untargeted_ResNet56v1_1': 0.09390000253915787,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet56v2_0': 0.01489999983459711,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_5': 0.06710000336170197,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet56v1_0': 0.026499999687075615,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_2': 0.08720000088214874,
#  'acc_1_on_adv_pgd_untargeted_ResNet20v2_0': 0.1428000032901764,
#  'acc_1_on_adv_pgd_untargeted_ResNet20v1_6': 0.1120000034570694,
#  'acc_1_on_adv_pgd_targeted_ll_ResNet20v1_4': 0.022600000724196434,
#  'acc_1_on_adv_cwl2_targeted_2nd_ResNet20v1_0': 0.2126999944448471,
#  'acc_1_on_adv_cwl2_targeted_ll_ResNet20v1_0': 0.6169999837875366}

# %%
accs = [eval_dict.get(f'acc_{i}', np.nan) for i in range(len(eval_dict))]
accs = np.array([v for k, v in eval_dict.items() if k.startswith('acc_')])

# %%
accs.shape
# Out:
# (115,)

# %%
loaded_models.keys()
# Out:
# dict_keys(['ResNet20v1_ff_cw-adv_0.keras', 'ResNet20v1_ff_cw-adv_1.keras', 'ResNet20v1_ff_cw-adv_2.keras', 'ResNet20v1_ff_cw-adv_3.keras', 'ResNet20v1_ff_targeted-adv_0.keras', 'ResNet20v1_ff_targeted-adv_1.keras', 'ResNet20v1_ff_targeted-adv_2.keras', 'ResNet20v1_ff_targeted-adv_3.keras', 'ResNet20v1_ff_untargeted-adv_0.keras', 'ResNet20v1_ff_untargeted-adv_1.keras', 'ResNet20v1_ff_untargeted-adv_2.keras', 'ResNet20v1_ff_untargeted-adv_3.keras', 'ResNet20v2_ff_cw-adv_0.keras', 'ResNet20v2_ff_cw-adv_1.keras', 'ResNet20v2_ff_cw-adv_2.keras', 'ResNet20v2_ff_cw-adv_3.keras', 'ResNet20v2_ff_targeted-adv_0.keras', 'ResNet20v2_ff_targeted-adv_1.keras', 'ResNet20v2_ff_targeted-adv_2.keras', 'ResNet20v2_ff_targeted-adv_3.keras', 'ResNet20v2_ff_untargeted-adv_0.keras', 'ResNet20v2_ff_untargeted-adv_1.keras', 'ResNet20v2_ff_untargeted-adv_2.keras', 'ResNet20v2_ff_untargeted-adv_3.keras', 'ResNet56v1_ff_cw-adv_0.keras', 'ResNet56v1_ff_cw-adv_1.keras', 'ResNet56v1_ff_cw-adv_2.keras', 'ResNet56v1_ff_cw-adv_3.keras', 'ResNet56v1_ff_targeted-adv_0.keras', 'ResNet56v1_ff_targeted-adv_1.keras', 'ResNet56v1_ff_targeted-adv_2.keras', 'ResNet56v1_ff_targeted-adv_3.keras', 'ResNet56v1_ff_untargeted-adv_0.keras', 'ResNet56v1_ff_untargeted-adv_1.keras', 'ResNet56v1_ff_untargeted-adv_2.keras', 'ResNet56v1_ff_untargeted-adv_3.keras', 'ResNet56v2_ff_cw-adv_0.keras', 'ResNet56v2_ff_cw-adv_1.keras', 'ResNet56v2_ff_cw-adv_2.keras', 'ResNet56v2_ff_cw-adv_3.keras', 'ResNet56v2_ff_targeted-adv_0.keras', 'ResNet56v2_ff_targeted-adv_1.keras', 'ResNet56v2_ff_targeted-adv_2.keras', 'ResNet56v2_ff_targeted-adv_3.keras', 'ResNet56v2_ff_untargeted-adv_0.keras', 'ResNet56v2_ff_untargeted-adv_1.keras', 'ResNet56v2_ff_untargeted-adv_2.keras', 'ResNet56v2_ff_untargeted-adv_3.keras'])
